# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# Loading in and dividing data
# reads in data
images = np.load("images.npy")
pv_out = np.load("pv_outputs.npy")

# randomly divides into a training set and a validation set
num_imgs = images.shape[0]
indices = np.arange(num_imgs)
np.random.shuffle(indices)
X_train, X_val = images[indices[:int(0.8 * num_imgs)]], images[indices[int(0.8 * num_imgs):]]
y_train, y_val = pv_out[indices[:int(0.8 * num_imgs)]], pv_out[indices[int(0.8 * num_imgs):]]

# %%
# The model
def cnn_model_depth5(X, y, is_training):
    # CBP sandwich 1
    conv1 = tf.layers.conv2d(
        inputs=X,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn1 = tf.layers.batch_normalization(inputs=conv1, axis=1)
    conv2 = tf.layers.conv2d(
        inputs=bn1,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn2 = tf.layers.batch_normalization(inputs=conv2, axis=1)
    conv3 = tf.layers.conv2d(
        inputs=bn2,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    pool1 = tf.layers.max_pooling2d(inputs=bn2, pool_size=[2, 2], strides=2)

    # CBP sandwich 2
    conv3 = tf.layers.conv2d(
        inputs=pool1,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    conv4 = tf.layers.conv2d(
        inputs=bn3,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn4 = tf.layers.batch_normalization(inputs=conv4, axis=1)

    
    pool2_flat = tf.reshape(bn4, [-1, 30 * 30 * 64])
    
    # Fully connected nets
    dense1 = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    bn_dense1 = tf.layers.batch_normalization(inputs=dense1)
    dropout1 = tf.layers.dropout(
        inputs=bn_dense1, rate=0.4, training=is_training)
    dense2 = tf.layers.dense(inputs=dropout1, units=1024, activation=tf.nn.relu)
    bn_dense2 = tf.layers.batch_normalization(inputs=dense2)
    dropout2 = tf.layers.dropout(
        inputs=bn_dense2, rate=0.4, training=is_training)
    dense3 = tf.layers.dense(inputs=dropout2, units=1024, activation=tf.nn.relu)
    bn_dense3 = tf.layers.batch_normalization(inputs=dense3)
    dropout3 = tf.layers.dropout(
        inputs=bn_dense3, rate=0.4, training=is_training)
    
    regression = tf.layers.dense(inputs=dropout3, units=1)
    regression = tf.reshape(regression, [-1])
    return regression

# %%
# Run model 
def run_model(session, pred_y_var, loss_var,
              x_var,y_var,is_training, Xd, yd,
              epoch_idx=0, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    rel_err_var = tf.divide(tf.abs(tf.subtract(y_var, pred_y_var)), y_var)
    accuracy = tf.reduce_mean(rel_err_var)

    # shuffle indices
    train_indices = np.arange(Xd.shape[0])
    np.random.shuffle(train_indices)
    training_now = training is not None

    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_var, rel_err_var, accuracy]
    if training_now:
        variables[-1] = training

    # counter
    iter_cnt = 0

    # keep track of losses and accuracy
    errors = 0
    losses = []

    # make sure we iterate over the dataset once
    for i in range(int(Xd.shape[0] / batch_size)+1):
        # generate indices for the batch
        start_idx = (i * batch_size) % Xd.shape[0]
        idx = train_indices[start_idx:start_idx + batch_size]

        # create a feed dictionary for this batch
        feed_dict = {x_var: Xd[idx, :],
                     y_var: yd[idx],
                     is_training: training_now}
        # get batch size
        actual_batch_size = yd[i:i + batch_size].shape[0]

        # have tensorflow compute loss and correct predictions
        # and (if given) perform a training step
        loss, rel_err, _ = session.run(variables, feed_dict=feed_dict)

        # aggregate performance stats
        losses.append(loss * actual_batch_size)
        errors += np.sum(rel_err)

        # print every now and then
        if training_now and (iter_cnt % print_every) == 0:
            print("Iteration {0}: with minibatch training loss = {1:.3g} and relative error of {2:.2g}"
                  .format(iter_cnt, loss, np.sum(rel_err) / actual_batch_size))
        iter_cnt += 1
    total_error = errors / Xd.shape[0]
    total_loss = np.sum(losses) / Xd.shape[0]

    print("Epoch {2}, Overall loss = {0:.3g} and relative error of {1:.3g}"
          .format(total_loss, total_error, epoch_idx+1 ))

    if plot_losses:
        plt.plot(losses)
        plt.grid(True)
        plt.title('Epoch {} Loss'.format(epoch_idx + 1))
        plt.xlabel('minibatch number')
        plt.ylabel('minibatch loss')
        plt.show()

    return total_loss, total_error

# %%
# Build computational graph
tf.reset_default_graph()  # Reset computational graph

x_var = tf.placeholder(tf.float32, [None, 60, 60, 3]) # x variable
y_var = tf.placeholder(tf.float32, [None]) # y variable
is_training = tf.placeholder(tf.bool) # flag
pred_y_var = cnn_model_depth5(x_var, y_var, is_training) # model in use
mean_loss = tf.losses.mean_squared_error(y_var, pred_y_var) # loss in use

# Define optimizer and optimize session parameter
# define optimizer
optimizer = tf.train.AdamOptimizer(1e-3)
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)
pass

# %%
# Train the model
# initialize all variable
num_epochs = 20
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# initialize loss and rel_err history list
train_loss_hist = []
train_error_hist = []
val_loss_hist = []
val_error_hist = []

for epoch_idx in range(num_epochs):
    print('Training')
    train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                        x_var,y_var,is_training,
                                        X_train, y_train, epoch_idx, 100, 20, train_step,False)
    print('Validation')
    val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                    x_var, y_var, is_training, X_val, y_val)
    
    train_loss_hist.append(train_loss)
    train_error_hist.append(train_error)
    val_loss_hist.append(val_loss)
    val_error_hist.append(val_error)

# Saving the model
model_name = "cnn_depth5"
saver = tf.train.Saver()
save_path = saver.save(sess, model_name + ".ckpt")
print("Model saved in file: %s" % save_path)

# Saving training history
train_loss = np.array(train_loss_hist)
np.save(model_name+"_train_loss", train_loss)
train_error = np.array(train_error_hist)
np.save(model_name+"_train_error", train_error)
val_loss = np.array(val_loss_hist)
np.save(model_name+"_val_loss", val_loss)
val_error = np.array(val_error_hist)
np.save(model_name+"_val_error", val_error)
# Out:
# Training
# Iteration 0: with minibatch training loss = 4.58e+06 and relative error of 1
# Iteration 20: with minibatch training loss = 1.63e+06 and relative error of 13
# Iteration 40: with minibatch training loss = 4.58e+05 and relative error of 3
# Iteration 60: with minibatch training loss = 6.23e+05 and relative error of 1.4
# Iteration 80: with minibatch training loss = 6.2e+05 and relative error of 1.6
# Iteration 100: with minibatch training loss = 6.12e+05 and relative error of 0.77
# Epoch 1, Overall loss = 9.08e+05 and relative error of 3.45
# Validation
# Epoch 1, Overall loss = 4e+05 and relative error of 2.27
# Training
# Iteration 0: with minibatch training loss = 5.82e+05 and relative error of 3.8
# Iteration 20: with minibatch training loss = 3.97e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 3.9e+05 and relative error of 1.2
# Iteration 60: with minibatch training loss = 3.62e+05 and relative error of 1.1
# Iteration 80: with minibatch training loss = 1.66e+05 and relative error of 0.75
# Iteration 100: with minibatch training loss = 2.51e+05 and relative error of 0.99
# Epoch 2, Overall loss = 3.16e+05 and relative error of 1.18
# Validation
# Epoch 1, Overall loss = 2.47e+05 and relative error of 1.33
# Training
# Iteration 0: with minibatch training loss = 3.43e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 2.03e+05 and relative error of 0.75
# Iteration 40: with minibatch training loss = 1.74e+05 and relative error of 1.3
# Iteration 60: with minibatch training loss = 1.61e+05 and relative error of 0.9
# Iteration 80: with minibatch training loss = 4.4e+05 and relative error of 1.3
# Iteration 100: with minibatch training loss = 2.97e+05 and relative error of 0.58
# Epoch 3, Overall loss = 2.46e+05 and relative error of 0.878
# Validation
# Epoch 1, Overall loss = 2.6e+05 and relative error of 1.31
# Training
# Iteration 0: with minibatch training loss = 3.27e+05 and relative error of 1.4
# Iteration 20: with minibatch training loss = 3.37e+05 and relative error of 0.89
# Iteration 40: with minibatch training loss = 2.17e+05 and relative error of 0.54
# Iteration 60: with minibatch training loss = 1.64e+05 and relative error of 0.66
# Iteration 80: with minibatch training loss = 3.39e+05 and relative error of 0.79
# Iteration 100: with minibatch training loss = 1.19e+05 and relative error of 0.41
# Epoch 4, Overall loss = 2.37e+05 and relative error of 0.792
# Validation
# Epoch 1, Overall loss = 1.66e+05 and relative error of 0.668
# Training
# Iteration 0: with minibatch training loss = 2.4e+05 and relative error of 0.42
# Iteration 20: with minibatch training loss = 1.48e+05 and relative error of 0.85
# Iteration 40: with minibatch training loss = 3.41e+05 and relative error of 0.78
# Iteration 60: with minibatch training loss = 2.31e+05 and relative error of 0.67
# Iteration 80: with minibatch training loss = 1.68e+05 and relative error of 0.61
# Iteration 100: with minibatch training loss = 2.33e+05 and relative error of 0.58
# Epoch 5, Overall loss = 2.16e+05 and relative error of 0.673
# Validation
# Epoch 1, Overall loss = 1.45e+05 and relative error of 0.603
# Training
# Iteration 0: with minibatch training loss = 1.4e+05 and relative error of 0.6
# Iteration 20: with minibatch training loss = 1.4e+05 and relative error of 0.3
# Iteration 40: with minibatch training loss = 1.66e+05 and relative error of 0.98
# Iteration 60: with minibatch training loss = 8.19e+04 and relative error of 0.66
# Iteration 80: with minibatch training loss = 3.18e+05 and relative error of 0.46
# Iteration 100: with minibatch training loss = 6.22e+04 and relative error of 0.63
# Epoch 6, Overall loss = 1.74e+05 and relative error of 0.597
# Validation
# Epoch 1, Overall loss = 1.9e+05 and relative error of 0.753
# Training
# Iteration 0: with minibatch training loss = 1.62e+05 and relative error of 0.69
# Iteration 20: with minibatch training loss = 1.23e+05 and relative error of 0.49
# Iteration 40: with minibatch training loss = 2.97e+05 and relative error of 0.54
# Iteration 60: with minibatch training loss = 8.99e+04 and relative error of 0.63
# Iteration 80: with minibatch training loss = 2.5e+05 and relative error of 0.51
# Iteration 100: with minibatch training loss = 1.55e+05 and relative error of 0.61
# Epoch 7, Overall loss = 1.58e+05 and relative error of 0.534
# Validation
# Epoch 1, Overall loss = 1.93e+05 and relative error of 0.498
# Training
# Iteration 0: with minibatch training loss = 1.34e+05 and relative error of 0.54
# Iteration 20: with minibatch training loss = 9.16e+04 and relative error of 0.54
# Iteration 40: with minibatch training loss = 1.17e+05 and relative error of 0.64
# Iteration 60: with minibatch training loss = 1.25e+05 and relative error of 0.42
# Iteration 80: with minibatch training loss = 1.67e+05 and relative error of 0.39
# Iteration 100: with minibatch training loss = 1.26e+05 and relative error of 0.5
# Epoch 8, Overall loss = 1.46e+05 and relative error of 0.558
# Validation
# Epoch 1, Overall loss = 1.55e+05 and relative error of 0.496
# Training
# Iteration 0: with minibatch training loss = 1.6e+05 and relative error of 0.41
# Iteration 20: with minibatch training loss = 2.41e+05 and relative error of 0.61
# Iteration 40: with minibatch training loss = 4.64e+04 and relative error of 0.33
# Iteration 60: with minibatch training loss = 1.21e+05 and relative error of 0.57
# Iteration 80: with minibatch training loss = 2.25e+05 and relative error of 0.45
# Iteration 100: with minibatch training loss = 1.35e+05 and relative error of 0.71
# Epoch 9, Overall loss = 1.54e+05 and relative error of 0.522
# Validation
# Epoch 1, Overall loss = 1.53e+05 and relative error of 0.545
# Training
# Iteration 0: with minibatch training loss = 1.39e+05 and relative error of 0.37
# Iteration 20: with minibatch training loss = 1.01e+05 and relative error of 0.45
# Iteration 40: with minibatch training loss = 5.48e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 9.08e+04 and relative error of 0.46
# Iteration 80: with minibatch training loss = 8.69e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 1.32e+05 and relative error of 0.54
# Epoch 10, Overall loss = 1.19e+05 and relative error of 0.424
# Validation
# Epoch 1, Overall loss = 1.31e+05 and relative error of 0.428
# Training
# Iteration 0: with minibatch training loss = 6.72e+04 and relative error of 0.46
# Iteration 20: with minibatch training loss = 6.61e+04 and relative error of 0.24
# Iteration 40: with minibatch training loss = 1.02e+05 and relative error of 0.3
# Iteration 60: with minibatch training loss = 1.32e+05 and relative error of 0.4
# Iteration 80: with minibatch training loss = 8.94e+04 and relative error of 0.34
# Iteration 100: with minibatch training loss = 8.1e+04 and relative error of 0.38
# Epoch 11, Overall loss = 1.15e+05 and relative error of 0.415
# Validation
# Epoch 1, Overall loss = 1.4e+05 and relative error of 0.465
# Training
# Iteration 0: with minibatch training loss = 6.4e+04 and relative error of 0.35
# Iteration 20: with minibatch training loss = 6.79e+04 and relative error of 0.58
# Iteration 40: with minibatch training loss = 8.33e+04 and relative error of 0.25
# Iteration 60: with minibatch training loss = 1.1e+05 and relative error of 0.23
# Iteration 80: with minibatch training loss = 3.79e+04 and relative error of 0.42
# Iteration 100: with minibatch training loss = 6e+04 and relative error of 0.2
# Epoch 12, Overall loss = 8.89e+04 and relative error of 0.371
# Validation
# Epoch 1, Overall loss = 1.61e+05 and relative error of 0.431
# Training
# Iteration 0: with minibatch training loss = 8.92e+04 and relative error of 0.4
# Iteration 20: with minibatch training loss = 1.1e+05 and relative error of 0.31
# Iteration 40: with minibatch training loss = 6.36e+04 and relative error of 0.34
# Iteration 60: with minibatch training loss = 1.45e+05 and relative error of 0.35
# Iteration 80: with minibatch training loss = 1.13e+05 and relative error of 0.53
# Iteration 100: with minibatch training loss = 1.18e+05 and relative error of 0.32
# Epoch 13, Overall loss = 9.64e+04 and relative error of 0.367
# Validation
# Epoch 1, Overall loss = 1.18e+05 and relative error of 0.403
# Training
# Iteration 0: with minibatch training loss = 6.03e+04 and relative error of 0.32
# Iteration 20: with minibatch training loss = 6.93e+04 and relative error of 0.42
# Iteration 40: with minibatch training loss = 7.22e+04 and relative error of 0.26
# Iteration 60: with minibatch training loss = 8.07e+04 and relative error of 0.23
# Iteration 80: with minibatch training loss = 4.65e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 4.36e+04 and relative error of 0.2
# Epoch 14, Overall loss = 7e+04 and relative error of 0.334
# Validation
# Epoch 1, Overall loss = 1.2e+05 and relative error of 0.407
# Training
# Iteration 0: with minibatch training loss = 4.93e+04 and relative error of 0.23
# Iteration 20: with minibatch training loss = 3.7e+04 and relative error of 0.29
# Iteration 40: with minibatch training loss = 8.64e+04 and relative error of 0.44
# Iteration 60: with minibatch training loss = 4.79e+04 and relative error of 0.21
# Iteration 80: with minibatch training loss = 1.9e+05 and relative error of 0.37
# Iteration 100: with minibatch training loss = 8.44e+04 and relative error of 0.33
# Epoch 15, Overall loss = 7.35e+04 and relative error of 0.327
# Validation
# Epoch 1, Overall loss = 1.15e+05 and relative error of 0.476
# Training
# Iteration 0: with minibatch training loss = 6.83e+04 and relative error of 0.41
# Iteration 20: with minibatch training loss = 4.21e+04 and relative error of 0.23
# Iteration 40: with minibatch training loss = 3.38e+04 and relative error of 0.25
# Iteration 60: with minibatch training loss = 7.5e+04 and relative error of 0.33
# Iteration 80: with minibatch training loss = 6.66e+04 and relative error of 0.19
# Iteration 100: with minibatch training loss = 6.31e+04 and relative error of 0.18
# Epoch 16, Overall loss = 6.27e+04 and relative error of 0.307
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.391
# Training
# Iteration 0: with minibatch training loss = 8.68e+04 and relative error of 0.25
# Iteration 20: with minibatch training loss = 8.28e+04 and relative error of 0.2
# Iteration 40: with minibatch training loss = 4.49e+04 and relative error of 0.46
# Iteration 60: with minibatch training loss = 7.88e+04 and relative error of 0.29
# Iteration 80: with minibatch training loss = 4.03e+04 and relative error of 0.27
# Iteration 100: with minibatch training loss = 6.17e+04 and relative error of 0.32
# Epoch 17, Overall loss = 6.54e+04 and relative error of 0.308
# Validation
# Epoch 1, Overall loss = 1.15e+05 and relative error of 0.362
# Training
# Iteration 0: with minibatch training loss = 3.78e+04 and relative error of 0.2
# Iteration 20: with minibatch training loss = 7.73e+04 and relative error of 0.25
# Iteration 40: with minibatch training loss = 7.94e+04 and relative error of 0.32
# Iteration 60: with minibatch training loss = 5.74e+04 and relative error of 0.22
# Iteration 80: with minibatch training loss = 5.52e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 8.37e+04 and relative error of 0.31
# Epoch 18, Overall loss = 6.07e+04 and relative error of 0.311
# Validation
# Epoch 1, Overall loss = 1.16e+05 and relative error of 0.413
# Training
# Iteration 0: with minibatch training loss = 5.15e+04 and relative error of 0.35
# Iteration 20: with minibatch training loss = 3.85e+04 and relative error of 0.36
# Iteration 40: with minibatch training loss = 5.46e+04 and relative error of 0.26
# Iteration 60: with minibatch training loss = 3.68e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 4.18e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 5.16e+04 and relative error of 0.36
# Epoch 19, Overall loss = 5.73e+04 and relative error of 0.303
# Validation
# Epoch 1, Overall loss = 1.27e+05 and relative error of 0.429
# Training
# Iteration 0: with minibatch training loss = 6.24e+04 and relative error of 0.35
# Iteration 20: with minibatch training loss = 4.34e+04 and relative error of 0.3
# Iteration 40: with minibatch training loss = 4.97e+04 and relative error of 0.33
# Iteration 60: with minibatch training loss = 8.07e+04 and relative error of 0.22
# Iteration 80: with minibatch training loss = 4.56e+04 and relative error of 0.21
# Iteration 100: with minibatch training loss = 2.91e+04 and relative error of 0.31
# Epoch 20, Overall loss = 6.11e+04 and relative error of 0.29
# Validation
# Epoch 1, Overall loss = 1.15e+05 and relative error of 0.428
# Model saved in file: cnn_depth5.ckpt

# %%
# loading the model
saver = tf.train.Saver()
sess = tf.Session()
save_path = "./cnn_depth5.ckpt"
saver.restore(sess, save_path)
print("Model restored.")
# Out:
# Model restored.

# %%
# Plotting final results
# plot training loss history
plt.plot(train_loss_hist,label= 'training loss history')
plt.plot(val_loss_hist,label= 'validation loss history')
plt.yscale('log')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('training loss')
plt.legend()
plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# plot relative error history
plt.plot(train_error_hist[7:], label='training relative error')
plt.plot(val_error_hist[7:], label='validation relative error')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('relative error')
plt.legend()
plt.savefig('relative_error.png', bbox_inches='tight')
plt.show()

# %%
idx1 = np.arange(0,491) # a sunny day at 12-20-16
idx2 = np.arange(2730,3145) # a cloudy day at 1-1-17
idx3 = np.arange(5420,5843) # a rainy  day at 1-8-17

idx = np.concatenate((idx1,idx2,idx3))

print(idx.shape)
# Out:
# (1329,)

# %%
idx= idx
feed_dict = {x_var: images[idx],y_var: pv_out[idx],is_training: False}

mse,pred_y_value = sess.run([mean_loss,pred_y_var], feed_dict=feed_dict)

plt.plot(pv_out[idx], label='actual pv output')
plt.plot(pred_y_value, label='predicted pv output')
plt.grid(True)
plt.xlabel('image index')
plt.ylabel('panel output (Btu/hr)')
plt.legend()
plt.savefig('predicted_and_actual_output.png', bbox_inches='tight')
plt.show()

print('RMSE: ', np.sqrt(mse))
# Out:
# RMSE:  303.08
