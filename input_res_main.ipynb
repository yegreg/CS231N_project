# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

dir_path = os.path.dirname(os.path.realpath("input_res_main.py"))
npy_folder = os.path.join(dir_path, "input_resolution")

# generate an array of input image shape
min_len = 32
max_len = 128
step_len = 8
output_img_len = np.arange(min_len, max_len + 1, step_len)

# %%
# The model
def cnn_73_model(X, y, is_training,side_len):
    # CBP sandwich 1
    conv1 = tf.layers.conv2d(
        inputs=X,
        filters=32,
        kernel_size=[7, 7],
        padding="same",
        activation=tf.nn.relu)
    bn1 = tf.layers.batch_normalization(inputs=conv1, axis=1)
    conv2 = tf.layers.conv2d(
        inputs=bn1,
        filters=32,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    bn2 = tf.layers.batch_normalization(inputs=conv2, axis=1)
    pool1 = tf.layers.max_pooling2d(inputs=bn2, pool_size=[2, 2], strides=2)

    # CBP sandwich 2
    conv3 = tf.layers.conv2d(
        inputs=pool1,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    conv4 = tf.layers.conv2d(
        inputs=bn3,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn4 = tf.layers.batch_normalization(inputs=conv4, axis=1)
    pool2 = tf.layers.max_pooling2d(inputs=bn4, pool_size=[2, 2], strides=2)
    

    # Two fully connected nets
    pool2_flat = tf.reshape(pool2, [-1, int(side_len/4*side_len/4*64)])
    dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    dropout = tf.layers.dropout(inputs=dense, rate=0.4, training=is_training)
    regression = tf.layers.dense(inputs=dropout, units=1)
    regression = tf.reshape(regression, [-1])
    return regression

# %%
# Run model 
def run_model(session, pred_y_var, loss_var,
              x_var,y_var,is_training, Xd, yd,
              epoch_idx=0, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    rel_err_var = tf.divide(tf.abs(tf.subtract(y_var, pred_y_var)), y_var)
    accuracy = tf.reduce_mean(rel_err_var)

    # shuffle indices
    train_indices = np.arange(Xd.shape[0])
    np.random.shuffle(train_indices)
    training_now = training is not None

    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_var, rel_err_var, accuracy]
    if training_now:
        variables[-1] = training

    # counter
    iter_cnt = 0

    # keep track of losses and accuracy
    errors = 0
    losses = []

    # make sure we iterate over the dataset once
    for i in range(int(Xd.shape[0] / batch_size)+1):
        # generate indices for the batch
        start_idx = (i * batch_size) % Xd.shape[0]
        idx = train_indices[start_idx:start_idx + batch_size]

        # create a feed dictionary for this batch
        feed_dict = {x_var: Xd[idx, :],
                     y_var: yd[idx],
                     is_training: training_now}
        # get batch size
        actual_batch_size = yd[i:i + batch_size].shape[0]

        # have tensorflow compute loss and correct predictions
        # and (if given) perform a training step
        loss, rel_err, _ = session.run(variables, feed_dict=feed_dict)

        # aggregate performance stats
        losses.append(loss * actual_batch_size)
        errors += np.sum(rel_err)

        # print every now and then
        if training_now and (iter_cnt % print_every) == 0:
            print("Iteration {0}: with minibatch training loss = {1:.3g} and relative error of {2:.2g}"
                  .format(iter_cnt, loss, np.sum(rel_err) / actual_batch_size))
        iter_cnt += 1
    total_error = errors / Xd.shape[0]
    total_loss = np.sum(losses) / Xd.shape[0]

    print("Epoch {2}, Overall loss = {0:.3g} and relative error of {1:.3g}"
          .format(total_loss, total_error, epoch_idx+1 ))

    if plot_losses:
        plt.plot(losses)
        plt.grid(True)
        plt.title('Epoch {} Loss'.format(epoch_idx + 1))
        plt.xlabel('minibatch number')
        plt.ylabel('minibatch loss')
        plt.show()

    return total_loss, total_error

# %%
# load PV output
pv_out = np.load(os.path.join(npy_folder,"pv_outputs.npy"))
num_epochs = 45

# initialize loss and rel_err history list
train_loss_hist = np.zeros([output_img_len.size, num_epochs], dtype='float32')
train_error_hist = np.zeros_like(train_loss_hist)
val_loss_hist = np.zeros_like(train_loss_hist)
val_error_hist = np.zeros_like(train_loss_hist)

for i in range(output_img_len.size):

    # Loading in and dividing data
    side_len = output_img_len[i]
    images = np.load(os.path.join(npy_folder, "images" + str(side_len) + ".npy"))

    # randomly divides into a training set and a validation set
    num_imgs = images.shape[0]
    indices = np.arange(num_imgs)
    np.random.shuffle(indices)
    X_train, X_val = images[indices[:int(0.8 * num_imgs)]], images[indices[int(0.8 * num_imgs):]]
    y_train, y_val = pv_out[indices[:int(0.8 * num_imgs)]], pv_out[indices[int(0.8 * num_imgs):]]

    # Build computational graph
    tf.reset_default_graph()  # Reset computational graph

    x_var = tf.placeholder(tf.float32, [None, side_len, side_len, 3])  # x variable
    y_var = tf.placeholder(tf.float32, [None])  # y variable
    is_training = tf.placeholder(tf.bool)  # flag
    pred_y_var = cnn_73_model(x_var, y_var, is_training,side_len)  # model in use
    mean_loss = tf.losses.mean_squared_error(y_var, pred_y_var)  # loss in use

    # Define optimizer and optimize session parameter
    # define optimizer
    optimizer = tf.train.AdamOptimizer(1e-3)
    # batch normalization in tensorflow requires this extra dependency
    extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

    with tf.control_dependencies(extra_update_ops):
        train_step = optimizer.minimize(mean_loss)
    pass

    with tf.Session() as sess:
        with tf.device("/gpu:0"): # cpu or gpu
            # initialize all variable
            sess.run(tf.global_variables_initializer())
    
            for epoch_idx in range(num_epochs):
                print('For image resolution {0}*{0}'.format(side_len))
                print('Training')
                train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                                    x_var, y_var, is_training,
                                                    X_train, y_train, epoch_idx, 100, 20, train_step, False)
                print('Validation')
                val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                                x_var, y_var, is_training, X_val, y_val)
    
                train_loss_hist[i, epoch_idx] = train_loss
                train_error_hist[i, epoch_idx] = train_error
                val_loss_hist[i, epoch_idx] = val_loss
                val_error_hist[i, epoch_idx] = val_error
# Out:
# Training
# Iteration 0: with minibatch training loss = 4.94e+06 and relative error of 0.97
# Iteration 20: with minibatch training loss = 2.29e+06 and relative error of 10
# Iteration 40: with minibatch training loss = 7.78e+05 and relative error of 3.6
# Iteration 60: with minibatch training loss = 7.12e+05 and relative error of 2.3
# Iteration 80: with minibatch training loss = 3.65e+05 and relative error of 3.5
# Iteration 100: with minibatch training loss = 4.23e+05 and relative error of 1.9
# Epoch 1, Overall loss = 1.11e+06 and relative error of 4.67
# Validation
# Epoch 1, Overall loss = 3.28e+05 and relative error of 2.08
# Training
# Iteration 0: with minibatch training loss = 5e+05 and relative error of 1.8
# Iteration 20: with minibatch training loss = 1.07e+05 and relative error of 1.9
# Iteration 40: with minibatch training loss = 3.34e+05 and relative error of 1.6
# Iteration 60: with minibatch training loss = 3.02e+05 and relative error of 1.9
# Iteration 80: with minibatch training loss = 3.23e+05 and relative error of 2.6
# Iteration 100: with minibatch training loss = 4.46e+05 and relative error of 1.3
# Epoch 2, Overall loss = 3.35e+05 and relative error of 1.97
# Validation
# Epoch 1, Overall loss = 2.81e+05 and relative error of 1.78
# Training
# Iteration 0: with minibatch training loss = 1.46e+05 and relative error of 1.6
# Iteration 20: with minibatch training loss = 5.8e+05 and relative error of 2.5
# Iteration 40: with minibatch training loss = 2.84e+05 and relative error of 2.4
# Iteration 60: with minibatch training loss = 2.44e+05 and relative error of 3.1
# Iteration 80: with minibatch training loss = 3.42e+05 and relative error of 1.7
# Iteration 100: with minibatch training loss = 3.86e+05 and relative error of 2.1
# Epoch 3, Overall loss = 3.11e+05 and relative error of 1.81
# Validation
# Epoch 1, Overall loss = 2.76e+05 and relative error of 2.17
# Training
# Iteration 0: with minibatch training loss = 3.18e+05 and relative error of 1.9
# Iteration 20: with minibatch training loss = 3.65e+05 and relative error of 2
# Iteration 40: with minibatch training loss = 3.48e+05 and relative error of 1.4
# Iteration 60: with minibatch training loss = 1.54e+05 and relative error of 0.97
# Iteration 80: with minibatch training loss = 8.33e+04 and relative error of 1.3
# Iteration 100: with minibatch training loss = 2.82e+05 and relative error of 1.2
# Epoch 4, Overall loss = 2.56e+05 and relative error of 1.61
# Validation
# Epoch 1, Overall loss = 2.54e+05 and relative error of 1.26
# Training
# Iteration 0: with minibatch training loss = 2.3e+05 and relative error of 1.1
# Iteration 20: with minibatch training loss = 2.98e+05 and relative error of 1.5
# Iteration 40: with minibatch training loss = 8.54e+04 and relative error of 1.6
# Iteration 60: with minibatch training loss = 1.83e+05 and relative error of 1.2
# Iteration 80: with minibatch training loss = 3.28e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 3.26e+05 and relative error of 1.1
# Epoch 5, Overall loss = 2.47e+05 and relative error of 1.51
# Validation
# Epoch 1, Overall loss = 2.3e+05 and relative error of 1.2
# Training
# Iteration 0: with minibatch training loss = 3.84e+06 and relative error of 0.96
# Iteration 20: with minibatch training loss = 1.07e+06 and relative error of 3.7
# Iteration 40: with minibatch training loss = 3.21e+05 and relative error of 2.5
# Iteration 60: with minibatch training loss = 3.62e+05 and relative error of 1.6
# Iteration 80: with minibatch training loss = 4.43e+05 and relative error of 2.9
# Iteration 100: with minibatch training loss = 3.43e+05 and relative error of 1
# Epoch 1, Overall loss = 6.97e+05 and relative error of 3.74
# Validation
# Epoch 1, Overall loss = 3.29e+05 and relative error of 1.8
# Training
# Iteration 0: with minibatch training loss = 2.37e+05 and relative error of 1.4
# Iteration 20: with minibatch training loss = 3e+05 and relative error of 2.1
# Iteration 40: with minibatch training loss = 1.79e+05 and relative error of 3
# Iteration 60: with minibatch training loss = 2.94e+05 and relative error of 1.3
# Iteration 80: with minibatch training loss = 3.82e+05 and relative error of 1
# Iteration 100: with minibatch training loss = 1.97e+05 and relative error of 0.93
# Epoch 2, Overall loss = 2.9e+05 and relative error of 1.55
# Validation
# Epoch 1, Overall loss = 2.65e+05 and relative error of 1.29
# Training
# Iteration 0: with minibatch training loss = 2.15e+05 and relative error of 1
# Iteration 20: with minibatch training loss = 3.9e+05 and relative error of 1.4
# Iteration 40: with minibatch training loss = 2.88e+05 and relative error of 1.3
# Iteration 60: with minibatch training loss = 2.92e+05 and relative error of 1.7
# Iteration 80: with minibatch training loss = 1.55e+05 and relative error of 1.4
# Iteration 100: with minibatch training loss = 5.26e+05 and relative error of 0.86
# Epoch 3, Overall loss = 2.59e+05 and relative error of 1.13
# Validation
# Epoch 1, Overall loss = 2.72e+05 and relative error of 1.01
# Training
# Iteration 0: with minibatch training loss = 3.23e+05 and relative error of 0.77
# Iteration 20: with minibatch training loss = 2.36e+05 and relative error of 0.37
# Iteration 40: with minibatch training loss = 1.63e+05 and relative error of 0.81
# Iteration 60: with minibatch training loss = 1.42e+05 and relative error of 0.57
# Iteration 80: with minibatch training loss = 3.55e+05 and relative error of 1.3
# Iteration 100: with minibatch training loss = 1.26e+05 and relative error of 0.98
# Epoch 4, Overall loss = 2.7e+05 and relative error of 0.907
# Validation
# Epoch 1, Overall loss = 2.17e+05 and relative error of 0.846
# Training
# Iteration 0: with minibatch training loss = 1.48e+05 and relative error of 0.61
# Iteration 20: with minibatch training loss = 1.59e+05 and relative error of 0.63
# Iteration 40: with minibatch training loss = 2.11e+05 and relative error of 0.83
# Iteration 60: with minibatch training loss = 3.53e+05 and relative error of 0.58
# Iteration 80: with minibatch training loss = 1.64e+05 and relative error of 0.99
# Iteration 100: with minibatch training loss = 2.21e+05 and relative error of 0.96
# Epoch 5, Overall loss = 2.29e+05 and relative error of 0.805
# Validation
# Epoch 1, Overall loss = 2.2e+05 and relative error of 0.684

# %%
np.save(os.path.join(npy_folder,"train_loss.npy"),train_loss_hist)
np.save(os.path.join(npy_folder,"train_error.npy"),train_error_hist)
np.save(os.path.join(npy_folder,"val_loss.npy"),val_loss_hist)
np.save(os.path.join(npy_folder,"val_error.npy"),val_error_hist)

# # Saving the model
# saver = tf.train.Saver()
# save_path = saver.save(sess, "G:\\Google Drive\\solar_research\\cnn7533.ckpt")
# print("Model saved in file: %s" % save_path)

# %%
# loading the model
saver = tf.train.Saver()
save_path = "cnn_7533.ckpt"
saver.restore(sess, save_path)

# %%
# Plotting final results
# plot training loss history
plt.plot(train_loss_hist,label= 'training loss history')
plt.plot(val_loss_hist,label= 'validation loss history')
plt.yscale('log')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('training loss')
plt.legend()
plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# plot relative error history
plt.plot(train_error_hist[7:], label='training relative error')
plt.plot(val_error_hist[7:], label='validation relative error')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('relative error')
plt.legend()
plt.savefig('relative_error.png', bbox_inches='tight')
plt.show()

# %%
idx1 = np.arange(0,491) # a sunny day at 12-20-16
idx2 = np.arange(2730,3145) # a cloudy day at 1-1-17
idx3 = np.arange(5420,5843) # a rainy  day at 1-8-17

idx = np.concatenate((idx1,idx2,idx3))

print(idx.shape)
# Out:
# (1329,)

# %%
idx= idx
feed_dict = {x_var: images[idx],y_var: pv_out[idx],is_training: False}

mse,pred_y_value = sess.run([mean_loss,pred_y_var], feed_dict=feed_dict)

plt.plot(pv_out[idx], label='actual pv output')
plt.plot(pred_y_value, label='predicted pv output')
plt.grid(True)
plt.xlabel('image index')
plt.ylabel('panel output (Btu/hr)')
plt.legend()
plt.savefig('predicted_and_actual_output.png', bbox_inches='tight')
plt.show()

print('RMSE: ', np.sqrt(mse))
# Out:
# RMSE:  343.589
