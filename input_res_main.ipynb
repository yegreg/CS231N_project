# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

dir_path = os.path.dirname(os.path.realpath("input_res_main.py"))
npy_folder = os.path.join(dir_path, "input_resolution")

# generate an array of input image shape
min_len = 32
max_len = 128
step_len = 8
output_img_len = np.arange(min_len, max_len + 1, step_len)

# %%
# The model
def cnn_73_model(X, y, is_training,side_len):
    # CBP sandwich 1
    conv1 = tf.layers.conv2d(
        inputs=X,
        filters=32,
        kernel_size=[7, 7],
        padding="same",
        activation=tf.nn.relu)
    bn1 = tf.layers.batch_normalization(inputs=conv1, axis=1)
    conv2 = tf.layers.conv2d(
        inputs=bn1,
        filters=32,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    bn2 = tf.layers.batch_normalization(inputs=conv2, axis=1)
    pool1 = tf.layers.max_pooling2d(inputs=bn2, pool_size=[2, 2], strides=2)

    # CBP sandwich 2
    conv3 = tf.layers.conv2d(
        inputs=pool1,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    conv4 = tf.layers.conv2d(
        inputs=bn3,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn4 = tf.layers.batch_normalization(inputs=conv4, axis=1)
    pool2 = tf.layers.max_pooling2d(inputs=bn4, pool_size=[2, 2], strides=2)
    

    # Two fully connected nets
    pool2_flat = tf.reshape(pool2, [-1, int(side_len/4*side_len/4*64)])
    dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    dropout = tf.layers.dropout(inputs=dense, rate=0.4, training=is_training)
    regression = tf.layers.dense(inputs=dropout, units=1)
    regression = tf.reshape(regression, [-1])
    return regression

# %%
# Run model 
def run_model(session, pred_y_var, loss_var,
              x_var,y_var,is_training, Xd, yd,
              epoch_idx=0, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    rel_err_var = tf.divide(tf.abs(tf.subtract(y_var, pred_y_var)), y_var)
    accuracy = tf.reduce_mean(rel_err_var)

    # shuffle indices
    train_indices = np.arange(Xd.shape[0])
    np.random.shuffle(train_indices)
    training_now = training is not None

    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_var, rel_err_var, accuracy]
    if training_now:
        variables[-1] = training

    # counter
    iter_cnt = 0

    # keep track of losses and accuracy
    errors = 0
    losses = []

    # make sure we iterate over the dataset once
    for i in range(int(Xd.shape[0] / batch_size)+1):
        # generate indices for the batch
        start_idx = (i * batch_size) % Xd.shape[0]
        idx = train_indices[start_idx:start_idx + batch_size]

        # create a feed dictionary for this batch
        feed_dict = {x_var: Xd[idx, :],
                     y_var: yd[idx],
                     is_training: training_now}
        # get batch size
        actual_batch_size = yd[i:i + batch_size].shape[0]

        # have tensorflow compute loss and correct predictions
        # and (if given) perform a training step
        loss, rel_err, _ = session.run(variables, feed_dict=feed_dict)

        # aggregate performance stats
        losses.append(loss * actual_batch_size)
        errors += np.sum(rel_err)

        # print every now and then
        if training_now and (iter_cnt % print_every) == 0:
            print("Iteration {0}: with minibatch training loss = {1:.3g} and relative error of {2:.2g}"
                  .format(iter_cnt, loss, np.sum(rel_err) / actual_batch_size))
        iter_cnt += 1
    total_error = errors / Xd.shape[0]
    total_loss = np.sum(losses) / Xd.shape[0]

    print("Epoch {2}, Overall loss = {0:.3g} and relative error of {1:.3g}"
          .format(total_loss, total_error, epoch_idx+1 ))

    if plot_losses:
        plt.plot(losses)
        plt.grid(True)
        plt.title('Epoch {} Loss'.format(epoch_idx + 1))
        plt.xlabel('minibatch number')
        plt.ylabel('minibatch loss')
        plt.show()

    return total_loss, total_error

# %%
# load PV output
pv_out = np.load(os.path.join(npy_folder,"pv_outputs.npy"))
num_epochs = 40

# initialize loss and rel_err history list
train_loss_hist = np.zeros([output_img_len.size, num_epochs], dtype='float32')
train_error_hist = np.zeros_like(train_loss_hist)
val_loss_hist = np.zeros_like(train_loss_hist)
val_error_hist = np.zeros_like(train_loss_hist)

for i in range(output_img_len.size):

    # Loading in and dividing data
    side_len = output_img_len[i]
    images = np.load(os.path.join(npy_folder, "images" + str(side_len) + ".npy"))

    # randomly divides into a training set and a validation set
    num_imgs = images.shape[0]
    indices = np.arange(num_imgs)
    np.random.shuffle(indices)
    X_train, X_val = images[indices[:int(0.8 * num_imgs)]], images[indices[int(0.8 * num_imgs):]]
    y_train, y_val = pv_out[indices[:int(0.8 * num_imgs)]], pv_out[indices[int(0.8 * num_imgs):]]

    # Build computational graph
    tf.reset_default_graph()  # Reset computational graph

    x_var = tf.placeholder(tf.float32, [None, side_len, side_len, 3])  # x variable
    y_var = tf.placeholder(tf.float32, [None])  # y variable
    is_training = tf.placeholder(tf.bool)  # flag
    pred_y_var = cnn_73_model(x_var, y_var, is_training,side_len)  # model in use
    mean_loss = tf.losses.mean_squared_error(y_var, pred_y_var)  # loss in use

    # Define optimizer and optimize session parameter
    # define optimizer
    optimizer = tf.train.AdamOptimizer(1e-3)
    # batch normalization in tensorflow requires this extra dependency
    extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

    with tf.control_dependencies(extra_update_ops):
        train_step = optimizer.minimize(mean_loss)
    pass

    with tf.Session() as sess:
        with tf.device("/gpu:0") as dev: # cpu or gpu
            # initialize all variable
            sess.run(tf.global_variables_initializer())
    
            for epoch_idx in range(num_epochs):
                print('For image resolution {0}*{0}'.format(side_len))
                print('Training')
                train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                                    x_var, y_var, is_training,
                                                    X_train, y_train, epoch_idx, 100, 20, train_step, False)
                print('Validation')
                val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                                x_var, y_var, is_training, X_val, y_val)
    
                train_loss_hist[i, epoch_idx] = train_loss
                train_error_hist[i, epoch_idx] = train_error
                val_loss_hist[i, epoch_idx] = val_loss
                val_error_hist[i, epoch_idx] = val_error
# Out:
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 5.61e+06 and relative error of 0.98
# Iteration 20: with minibatch training loss = 1.65e+06 and relative error of 15
# Iteration 40: with minibatch training loss = 8.05e+05 and relative error of 3
# Iteration 60: with minibatch training loss = 6.57e+05 and relative error of 5.4
# Iteration 80: with minibatch training loss = 3.16e+05 and relative error of 1.8
# Iteration 100: with minibatch training loss = 3.79e+05 and relative error of 1.4
# Epoch 1, Overall loss = 9.49e+05 and relative error of 4.58
# Validation
# Epoch 1, Overall loss = 3.47e+05 and relative error of 1.47
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 2.03e+05 and relative error of 1.6
# Iteration 20: with minibatch training loss = 3.8e+05 and relative error of 1.5
# Iteration 40: with minibatch training loss = 3.1e+05 and relative error of 2.1
# Iteration 60: with minibatch training loss = 4.51e+05 and relative error of 0.94
# Iteration 80: with minibatch training loss = 5.15e+05 and relative error of 2.3
# Iteration 100: with minibatch training loss = 1.8e+05 and relative error of 2.3
# Epoch 2, Overall loss = 3.44e+05 and relative error of 1.9
# Validation
# Epoch 1, Overall loss = 2.71e+05 and relative error of 1.3
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 3.21e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 2.96e+05 and relative error of 1.4
# Iteration 40: with minibatch training loss = 2.63e+05 and relative error of 2
# Iteration 60: with minibatch training loss = 5.48e+05 and relative error of 1.8
# Iteration 80: with minibatch training loss = 1.96e+05 and relative error of 1.2
# Iteration 100: with minibatch training loss = 2.46e+05 and relative error of 2.1
# Epoch 3, Overall loss = 2.83e+05 and relative error of 1.65
# Validation
# Epoch 1, Overall loss = 2.18e+05 and relative error of 1.67
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.81e+05 and relative error of 1.9
# Iteration 20: with minibatch training loss = 1.92e+05 and relative error of 1.7
# Iteration 40: with minibatch training loss = 3.95e+05 and relative error of 1.2
# Iteration 60: with minibatch training loss = 1.01e+05 and relative error of 1.6
# Iteration 80: with minibatch training loss = 2.56e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 2.7e+05 and relative error of 1.2
# Epoch 4, Overall loss = 2.7e+05 and relative error of 1.58
# Validation
# Epoch 1, Overall loss = 2.09e+05 and relative error of 1.11
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.9e+05 and relative error of 1
# Iteration 20: with minibatch training loss = 1.15e+05 and relative error of 1.5
# Iteration 40: with minibatch training loss = 2.73e+05 and relative error of 0.99
# Iteration 60: with minibatch training loss = 1.77e+05 and relative error of 1.2
# Iteration 80: with minibatch training loss = 1.95e+05 and relative error of 1.4
# Iteration 100: with minibatch training loss = 4.35e+05 and relative error of 0.87
# Epoch 5, Overall loss = 2.44e+05 and relative error of 1.35
# Validation
# Epoch 1, Overall loss = 3.49e+05 and relative error of 1.99
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 2.86e+05 and relative error of 2.4
# Iteration 20: with minibatch training loss = 1.35e+05 and relative error of 1.8
# Iteration 40: with minibatch training loss = 1.39e+05 and relative error of 0.73
# Iteration 60: with minibatch training loss = 1.1e+05 and relative error of 1.4
# Iteration 80: with minibatch training loss = 1.34e+05 and relative error of 1.2
# Iteration 100: with minibatch training loss = 2.41e+05 and relative error of 0.81
# Epoch 6, Overall loss = 2.18e+05 and relative error of 1.23
# Validation
# Epoch 1, Overall loss = 1.8e+05 and relative error of 1.15
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 2.15e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 2.51e+05 and relative error of 0.72
# Iteration 40: with minibatch training loss = 1.49e+05 and relative error of 1.4
# Iteration 60: with minibatch training loss = 2.73e+05 and relative error of 0.9
# Iteration 80: with minibatch training loss = 3.26e+05 and relative error of 0.91
# Iteration 100: with minibatch training loss = 2.43e+05 and relative error of 1.1
# Epoch 7, Overall loss = 1.9e+05 and relative error of 1.07
# Validation
# Epoch 1, Overall loss = 1.66e+05 and relative error of 0.757
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.82e+05 and relative error of 1.2
# Iteration 20: with minibatch training loss = 2.23e+05 and relative error of 1.2
# Iteration 40: with minibatch training loss = 1.51e+05 and relative error of 0.99
# Iteration 60: with minibatch training loss = 2.55e+05 and relative error of 0.65
# Iteration 80: with minibatch training loss = 7.28e+04 and relative error of 0.83
# Iteration 100: with minibatch training loss = 2.77e+05 and relative error of 0.84
# Epoch 8, Overall loss = 1.89e+05 and relative error of 1.03
# Validation
# Epoch 1, Overall loss = 1.9e+05 and relative error of 0.679
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.69e+05 and relative error of 0.63
# Iteration 20: with minibatch training loss = 2.8e+05 and relative error of 0.76
# Iteration 40: with minibatch training loss = 1.8e+05 and relative error of 1.2
# Iteration 60: with minibatch training loss = 1.79e+05 and relative error of 1.1
# Iteration 80: with minibatch training loss = 1.57e+05 and relative error of 0.7
# Iteration 100: with minibatch training loss = 9.92e+04 and relative error of 1.4
# Epoch 9, Overall loss = 1.83e+05 and relative error of 1.03
# Validation
# Epoch 1, Overall loss = 1.6e+05 and relative error of 0.61
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.05e+05 and relative error of 0.65
# Iteration 20: with minibatch training loss = 1.2e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 1.79e+05 and relative error of 0.81
# Iteration 60: with minibatch training loss = 2.05e+05 and relative error of 0.84
# Iteration 80: with minibatch training loss = 1.13e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 2.08e+05 and relative error of 0.96
# Epoch 10, Overall loss = 1.81e+05 and relative error of 0.948
# Validation
# Epoch 1, Overall loss = 1.72e+05 and relative error of 1.05
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.5e+05 and relative error of 0.93
# Iteration 20: with minibatch training loss = 3.05e+05 and relative error of 0.99
# Iteration 40: with minibatch training loss = 8.56e+04 and relative error of 1
# Iteration 60: with minibatch training loss = 1.95e+05 and relative error of 1
# Iteration 80: with minibatch training loss = 1.48e+05 and relative error of 1.2
# Iteration 100: with minibatch training loss = 1.87e+05 and relative error of 0.82
# Epoch 11, Overall loss = 1.83e+05 and relative error of 0.941
# Validation
# Epoch 1, Overall loss = 1.45e+05 and relative error of 0.793
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.17e+05 and relative error of 0.66
# Iteration 20: with minibatch training loss = 1.72e+05 and relative error of 1.5
# Iteration 40: with minibatch training loss = 1e+05 and relative error of 0.71
# Iteration 60: with minibatch training loss = 2.07e+05 and relative error of 0.81
# Iteration 80: with minibatch training loss = 1.25e+05 and relative error of 0.55
# Iteration 100: with minibatch training loss = 1.21e+05 and relative error of 0.8
# Epoch 12, Overall loss = 1.63e+05 and relative error of 0.88
# Validation
# Epoch 1, Overall loss = 1.37e+05 and relative error of 0.682
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.51e+05 and relative error of 1.2
# Iteration 20: with minibatch training loss = 2.03e+05 and relative error of 0.62
# Iteration 40: with minibatch training loss = 5.47e+04 and relative error of 0.81
# Iteration 60: with minibatch training loss = 1.65e+05 and relative error of 0.75
# Iteration 80: with minibatch training loss = 2.16e+05 and relative error of 1.8
# Iteration 100: with minibatch training loss = 9.2e+04 and relative error of 0.57
# Epoch 13, Overall loss = 1.66e+05 and relative error of 0.887
# Validation
# Epoch 1, Overall loss = 2.41e+05 and relative error of 0.561
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 2.49e+05 and relative error of 0.49
# Iteration 20: with minibatch training loss = 1.27e+05 and relative error of 0.79
# Iteration 40: with minibatch training loss = 3e+05 and relative error of 1.1
# Iteration 60: with minibatch training loss = 3.38e+05 and relative error of 0.77
# Iteration 80: with minibatch training loss = 1.42e+05 and relative error of 0.82
# Iteration 100: with minibatch training loss = 5e+04 and relative error of 0.73
# Epoch 14, Overall loss = 1.53e+05 and relative error of 0.824
# Validation
# Epoch 1, Overall loss = 1.6e+05 and relative error of 0.898
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.7e+05 and relative error of 1.2
# Iteration 20: with minibatch training loss = 8.69e+04 and relative error of 0.79
# Iteration 40: with minibatch training loss = 2.34e+05 and relative error of 0.73
# Iteration 60: with minibatch training loss = 1.34e+05 and relative error of 1.4
# Iteration 80: with minibatch training loss = 6.44e+04 and relative error of 0.94
# Iteration 100: with minibatch training loss = 2.34e+05 and relative error of 0.79
# Epoch 15, Overall loss = 1.54e+05 and relative error of 0.824
# Validation
# Epoch 1, Overall loss = 1.31e+05 and relative error of 0.669
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 9.68e+04 and relative error of 0.82
# Iteration 20: with minibatch training loss = 2.5e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 1.05e+05 and relative error of 0.74
# Iteration 60: with minibatch training loss = 1.27e+05 and relative error of 0.48
# Iteration 80: with minibatch training loss = 1.68e+05 and relative error of 0.88
# Iteration 100: with minibatch training loss = 8.91e+04 and relative error of 0.86
# Epoch 16, Overall loss = 1.35e+05 and relative error of 0.776
# Validation
# Epoch 1, Overall loss = 1.2e+05 and relative error of 0.579
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.55e+05 and relative error of 0.7
# Iteration 20: with minibatch training loss = 1.25e+05 and relative error of 0.91
# Iteration 40: with minibatch training loss = 1.19e+05 and relative error of 0.61
# Iteration 60: with minibatch training loss = 1.14e+05 and relative error of 0.52
# Iteration 80: with minibatch training loss = 8.1e+04 and relative error of 0.83
# Iteration 100: with minibatch training loss = 3.13e+05 and relative error of 0.52
# Epoch 17, Overall loss = 1.33e+05 and relative error of 0.735
# Validation
# Epoch 1, Overall loss = 1.21e+05 and relative error of 0.611
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 9e+04 and relative error of 0.88
# Iteration 20: with minibatch training loss = 1.18e+05 and relative error of 0.91
# Iteration 40: with minibatch training loss = 1.88e+05 and relative error of 0.8
# Iteration 60: with minibatch training loss = 7.83e+04 and relative error of 0.72
# Iteration 80: with minibatch training loss = 1.01e+05 and relative error of 0.84
# Iteration 100: with minibatch training loss = 9.83e+04 and relative error of 0.72
# Epoch 18, Overall loss = 1.28e+05 and relative error of 0.731
# Validation
# Epoch 1, Overall loss = 1.14e+05 and relative error of 0.493
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.14e+05 and relative error of 0.56
# Iteration 20: with minibatch training loss = 7.8e+04 and relative error of 0.43
# Iteration 40: with minibatch training loss = 1.58e+05 and relative error of 0.81
# Iteration 60: with minibatch training loss = 5.55e+04 and relative error of 0.96
# Iteration 80: with minibatch training loss = 1.36e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 1.36e+05 and relative error of 1.1
# Epoch 19, Overall loss = 1.24e+05 and relative error of 0.7
# Validation
# Epoch 1, Overall loss = 1.66e+05 and relative error of 0.44
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.77e+05 and relative error of 0.42
# Iteration 20: with minibatch training loss = 1.41e+05 and relative error of 0.9
# Iteration 40: with minibatch training loss = 7.76e+04 and relative error of 0.51
# Iteration 60: with minibatch training loss = 9.44e+04 and relative error of 0.62
# Iteration 80: with minibatch training loss = 8.53e+04 and relative error of 0.38
# Iteration 100: with minibatch training loss = 6.88e+04 and relative error of 0.57
# Epoch 20, Overall loss = 1.23e+05 and relative error of 0.709
# Validation
# Epoch 1, Overall loss = 1.33e+05 and relative error of 0.688
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.21e+05 and relative error of 0.62
# Iteration 20: with minibatch training loss = 1.04e+05 and relative error of 0.67
# Iteration 40: with minibatch training loss = 6.53e+04 and relative error of 1.1
# Iteration 60: with minibatch training loss = 1.13e+05 and relative error of 0.53
# Iteration 80: with minibatch training loss = 2.48e+05 and relative error of 0.68
# Iteration 100: with minibatch training loss = 1.44e+05 and relative error of 1.1
# Epoch 21, Overall loss = 1.22e+05 and relative error of 0.68
# Validation
# Epoch 1, Overall loss = 1.18e+05 and relative error of 0.622
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 7.3e+04 and relative error of 0.86
# Iteration 20: with minibatch training loss = 8.42e+04 and relative error of 0.39
# Iteration 40: with minibatch training loss = 1.05e+05 and relative error of 0.57
# Iteration 60: with minibatch training loss = 7.87e+04 and relative error of 0.8
# Iteration 80: with minibatch training loss = 8.09e+04 and relative error of 0.59
# Iteration 100: with minibatch training loss = 1.31e+05 and relative error of 0.44
# Epoch 22, Overall loss = 1.1e+05 and relative error of 0.665
# Validation
# Epoch 1, Overall loss = 1.12e+05 and relative error of 0.448
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 6.23e+04 and relative error of 0.59
# Iteration 20: with minibatch training loss = 1.44e+05 and relative error of 0.56
# Iteration 40: with minibatch training loss = 1.02e+05 and relative error of 0.55
# Iteration 60: with minibatch training loss = 1.65e+05 and relative error of 0.45
# Iteration 80: with minibatch training loss = 1.3e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 4.59e+04 and relative error of 0.61
# Epoch 23, Overall loss = 1.08e+05 and relative error of 0.635
# Validation
# Epoch 1, Overall loss = 1.29e+05 and relative error of 0.578
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 7.39e+04 and relative error of 0.84
# Iteration 20: with minibatch training loss = 6.79e+04 and relative error of 0.57
# Iteration 40: with minibatch training loss = 8.87e+04 and relative error of 0.61
# Iteration 60: with minibatch training loss = 1.33e+05 and relative error of 0.58
# Iteration 80: with minibatch training loss = 1.26e+05 and relative error of 0.76
# Iteration 100: with minibatch training loss = 4.98e+04 and relative error of 0.68
# Epoch 24, Overall loss = 1.01e+05 and relative error of 0.616
# Validation
# Epoch 1, Overall loss = 1.68e+05 and relative error of 0.635
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 8.85e+04 and relative error of 0.66
# Iteration 20: with minibatch training loss = 1.1e+05 and relative error of 0.69
# Iteration 40: with minibatch training loss = 4.11e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 6.52e+04 and relative error of 0.47
# Iteration 80: with minibatch training loss = 1.35e+05 and relative error of 1
# Iteration 100: with minibatch training loss = 5.9e+04 and relative error of 0.54
# Epoch 25, Overall loss = 9.94e+04 and relative error of 0.603
# Validation
# Epoch 1, Overall loss = 1.14e+05 and relative error of 0.503
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 5.09e+04 and relative error of 0.66
# Iteration 20: with minibatch training loss = 3.13e+04 and relative error of 0.39
# Iteration 40: with minibatch training loss = 1.23e+05 and relative error of 0.54
# Iteration 60: with minibatch training loss = 1.15e+05 and relative error of 0.42
# Iteration 80: with minibatch training loss = 2.95e+04 and relative error of 0.47
# Iteration 100: with minibatch training loss = 8.68e+04 and relative error of 0.78
# Epoch 26, Overall loss = 1.01e+05 and relative error of 0.595
# Validation
# Epoch 1, Overall loss = 1.34e+05 and relative error of 0.531
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 7.84e+04 and relative error of 0.55
# Iteration 20: with minibatch training loss = 8.11e+04 and relative error of 0.58
# Iteration 40: with minibatch training loss = 5.33e+04 and relative error of 0.28
# Iteration 60: with minibatch training loss = 6.68e+04 and relative error of 0.57
# Iteration 80: with minibatch training loss = 7.68e+04 and relative error of 0.75
# Iteration 100: with minibatch training loss = 2.15e+05 and relative error of 0.5
# Epoch 27, Overall loss = 9.33e+04 and relative error of 0.566
# Validation
# Epoch 1, Overall loss = 1.44e+05 and relative error of 0.414
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.06e+05 and relative error of 0.41
# Iteration 20: with minibatch training loss = 8.37e+04 and relative error of 0.65
# Iteration 40: with minibatch training loss = 4.5e+04 and relative error of 0.35
# Iteration 60: with minibatch training loss = 1.14e+05 and relative error of 0.67
# Iteration 80: with minibatch training loss = 8.01e+04 and relative error of 0.54
# Iteration 100: with minibatch training loss = 8.73e+04 and relative error of 0.51
# Epoch 28, Overall loss = 9.14e+04 and relative error of 0.576
# Validation
# Epoch 1, Overall loss = 1.33e+05 and relative error of 0.42
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 9.31e+04 and relative error of 0.75
# Iteration 20: with minibatch training loss = 9.1e+04 and relative error of 0.53
# Iteration 40: with minibatch training loss = 3.68e+04 and relative error of 0.5
# Iteration 60: with minibatch training loss = 5.02e+04 and relative error of 0.4
# Iteration 80: with minibatch training loss = 1.74e+05 and relative error of 0.77
# Iteration 100: with minibatch training loss = 6.72e+04 and relative error of 0.44
# Epoch 29, Overall loss = 9.23e+04 and relative error of 0.564
# Validation
# Epoch 1, Overall loss = 1.12e+05 and relative error of 0.501
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 4e+04 and relative error of 0.5
# Iteration 20: with minibatch training loss = 1.15e+05 and relative error of 0.37
# Iteration 40: with minibatch training loss = 1.25e+05 and relative error of 0.55
# Iteration 60: with minibatch training loss = 8.6e+04 and relative error of 0.67
# Iteration 80: with minibatch training loss = 8.23e+04 and relative error of 0.63
# Iteration 100: with minibatch training loss = 4.11e+04 and relative error of 0.48
# Epoch 30, Overall loss = 7.58e+04 and relative error of 0.534
# Validation
# Epoch 1, Overall loss = 1.2e+05 and relative error of 0.549
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 5.72e+04 and relative error of 0.76
# Iteration 20: with minibatch training loss = 3.86e+04 and relative error of 0.56
# Iteration 40: with minibatch training loss = 8.46e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 6.28e+04 and relative error of 0.47
# Iteration 80: with minibatch training loss = 3.78e+04 and relative error of 0.36
# Iteration 100: with minibatch training loss = 7.28e+04 and relative error of 0.51
# Epoch 31, Overall loss = 7.4e+04 and relative error of 0.53
# Validation
# Epoch 1, Overall loss = 1.4e+05 and relative error of 0.575
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.1e+05 and relative error of 0.96
# Iteration 20: with minibatch training loss = 1.1e+05 and relative error of 0.45
# Iteration 40: with minibatch training loss = 6.16e+04 and relative error of 0.53
# Iteration 60: with minibatch training loss = 1.03e+05 and relative error of 0.39
# Iteration 80: with minibatch training loss = 7.64e+04 and relative error of 0.45
# Iteration 100: with minibatch training loss = 3.76e+04 and relative error of 0.4
# Epoch 32, Overall loss = 8.16e+04 and relative error of 0.551
# Validation
# Epoch 1, Overall loss = 1.12e+05 and relative error of 0.406
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 3.69e+04 and relative error of 0.32
# Iteration 20: with minibatch training loss = 6.58e+04 and relative error of 0.43
# Iteration 40: with minibatch training loss = 4.74e+04 and relative error of 0.39
# Iteration 60: with minibatch training loss = 4.1e+04 and relative error of 0.52
# Iteration 80: with minibatch training loss = 1.04e+05 and relative error of 0.57
# Iteration 100: with minibatch training loss = 4.75e+04 and relative error of 0.58
# Epoch 33, Overall loss = 7.64e+04 and relative error of 0.519
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.438
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 8.03e+04 and relative error of 0.36
# Iteration 20: with minibatch training loss = 1.39e+05 and relative error of 0.35
# Iteration 40: with minibatch training loss = 5.64e+04 and relative error of 0.52
# Iteration 60: with minibatch training loss = 4.29e+04 and relative error of 0.51
# Iteration 80: with minibatch training loss = 5.24e+04 and relative error of 0.88
# Iteration 100: with minibatch training loss = 5.24e+04 and relative error of 0.52
# Epoch 34, Overall loss = 7.56e+04 and relative error of 0.523
# Validation
# Epoch 1, Overall loss = 1.07e+05 and relative error of 0.466
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 4.13e+04 and relative error of 0.47
# Iteration 20: with minibatch training loss = 4.75e+04 and relative error of 0.33
# Iteration 40: with minibatch training loss = 9.18e+04 and relative error of 0.4
# Iteration 60: with minibatch training loss = 1.03e+05 and relative error of 0.36
# Iteration 80: with minibatch training loss = 5e+04 and relative error of 0.37
# Iteration 100: with minibatch training loss = 7.9e+04 and relative error of 0.42
# Epoch 35, Overall loss = 7.49e+04 and relative error of 0.492
# Validation
# Epoch 1, Overall loss = 1.22e+05 and relative error of 0.369
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 9.21e+04 and relative error of 0.6
# Iteration 20: with minibatch training loss = 5.59e+04 and relative error of 0.56
# Iteration 40: with minibatch training loss = 1.31e+05 and relative error of 1.1
# Iteration 60: with minibatch training loss = 5.81e+04 and relative error of 0.59
# Iteration 80: with minibatch training loss = 7.3e+04 and relative error of 0.36
# Iteration 100: with minibatch training loss = 7.68e+04 and relative error of 0.49
# Epoch 36, Overall loss = 7.14e+04 and relative error of 0.487
# Validation
# Epoch 1, Overall loss = 1.82e+05 and relative error of 0.373
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 1.61e+05 and relative error of 0.37
# Iteration 20: with minibatch training loss = 5.51e+04 and relative error of 0.45
# Iteration 40: with minibatch training loss = 6.97e+04 and relative error of 0.54
# Iteration 60: with minibatch training loss = 1.07e+05 and relative error of 0.44
# Iteration 80: with minibatch training loss = 7.29e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 4.72e+04 and relative error of 0.61
# Epoch 37, Overall loss = 7.08e+04 and relative error of 0.486
# Validation
# Epoch 1, Overall loss = 1.12e+05 and relative error of 0.424
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 4.72e+04 and relative error of 0.38
# Iteration 20: with minibatch training loss = 8.23e+04 and relative error of 0.31
# Iteration 40: with minibatch training loss = 4.62e+04 and relative error of 0.39
# Iteration 60: with minibatch training loss = 6.99e+04 and relative error of 0.42
# Iteration 80: with minibatch training loss = 8.14e+04 and relative error of 0.3
# Iteration 100: with minibatch training loss = 5.04e+04 and relative error of 0.49
# Epoch 38, Overall loss = 6.36e+04 and relative error of 0.461
# Validation
# Epoch 1, Overall loss = 1.23e+05 and relative error of 0.363
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 5.87e+04 and relative error of 0.38
# Iteration 20: with minibatch training loss = 7.02e+04 and relative error of 0.42
# Iteration 40: with minibatch training loss = 3.51e+04 and relative error of 0.33
# Iteration 60: with minibatch training loss = 5.3e+04 and relative error of 0.36
# Iteration 80: with minibatch training loss = 3.43e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 5.75e+04 and relative error of 0.44
# Epoch 39, Overall loss = 6.23e+04 and relative error of 0.456
# Validation
# Epoch 1, Overall loss = 1.1e+05 and relative error of 0.479
# For image resolution 32*32
# Training
# Iteration 0: with minibatch training loss = 4.43e+04 and relative error of 0.63
# Iteration 20: with minibatch training loss = 5.71e+04 and relative error of 0.36
# Iteration 40: with minibatch training loss = 4.64e+04 and relative error of 0.5
# Iteration 60: with minibatch training loss = 4.02e+04 and relative error of 0.49
# Iteration 80: with minibatch training loss = 2.6e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 6.03e+04 and relative error of 0.42
# Epoch 40, Overall loss = 5.63e+04 and relative error of 0.445
# Validation
# Epoch 1, Overall loss = 1.49e+05 and relative error of 0.449
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 5.03e+06 and relative error of 0.87
# Iteration 20: with minibatch training loss = 2.45e+06 and relative error of 9.2
# Iteration 40: with minibatch training loss = 1.71e+06 and relative error of 12
# Iteration 60: with minibatch training loss = 1.2e+06 and relative error of 2.5
# Iteration 80: with minibatch training loss = 3.68e+05 and relative error of 2.9
# Iteration 100: with minibatch training loss = 3.55e+05 and relative error of 1.8
# Epoch 1, Overall loss = 1.49e+06 and relative error of 5.14
# Validation
# Epoch 1, Overall loss = 3.56e+05 and relative error of 2.09
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.62e+05 and relative error of 1.8
# Iteration 20: with minibatch training loss = 2.54e+05 and relative error of 1.7
# Iteration 40: with minibatch training loss = 2.1e+05 and relative error of 1.6
# Iteration 60: with minibatch training loss = 2.03e+05 and relative error of 2.1
# Iteration 80: with minibatch training loss = 2.9e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 5.22e+05 and relative error of 1.6
# Epoch 2, Overall loss = 3.07e+05 and relative error of 1.66
# Validation
# Epoch 1, Overall loss = 2.28e+05 and relative error of 1.22
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 3.66e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 1.63e+05 and relative error of 1.2
# Iteration 40: with minibatch training loss = 1.67e+05 and relative error of 1.3
# Iteration 60: with minibatch training loss = 3.81e+05 and relative error of 1.2
# Iteration 80: with minibatch training loss = 2.09e+05 and relative error of 0.69
# Iteration 100: with minibatch training loss = 1.31e+05 and relative error of 1.1
# Epoch 3, Overall loss = 2.43e+05 and relative error of 1.15
# Validation
# Epoch 1, Overall loss = 2.58e+05 and relative error of 0.84
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.16e+05 and relative error of 0.99
# Iteration 20: with minibatch training loss = 6.09e+04 and relative error of 1.3
# Iteration 40: with minibatch training loss = 1.49e+05 and relative error of 1.2
# Iteration 60: with minibatch training loss = 4.19e+05 and relative error of 0.51
# Iteration 80: with minibatch training loss = 2.37e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 2.09e+05 and relative error of 1.1
# Epoch 4, Overall loss = 2.38e+05 and relative error of 0.961
# Validation
# Epoch 1, Overall loss = 1.97e+05 and relative error of 0.925
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.85e+05 and relative error of 1.1
# Iteration 20: with minibatch training loss = 1.92e+05 and relative error of 1.5
# Iteration 40: with minibatch training loss = 1.73e+05 and relative error of 1.2
# Iteration 60: with minibatch training loss = 2.56e+05 and relative error of 0.94
# Iteration 80: with minibatch training loss = 1.71e+05 and relative error of 0.49
# Iteration 100: with minibatch training loss = 1.58e+05 and relative error of 0.53
# Epoch 5, Overall loss = 2.36e+05 and relative error of 0.898
# Validation
# Epoch 1, Overall loss = 1.95e+05 and relative error of 0.999
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.29e+05 and relative error of 0.66
# Iteration 20: with minibatch training loss = 2.33e+05 and relative error of 0.56
# Iteration 40: with minibatch training loss = 1.28e+05 and relative error of 0.57
# Iteration 60: with minibatch training loss = 3.5e+05 and relative error of 0.82
# Iteration 80: with minibatch training loss = 1.33e+05 and relative error of 0.76
# Iteration 100: with minibatch training loss = 2.26e+05 and relative error of 0.95
# Epoch 6, Overall loss = 1.99e+05 and relative error of 0.778
# Validation
# Epoch 1, Overall loss = 2.3e+05 and relative error of 0.508
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.07e+05 and relative error of 0.61
# Iteration 20: with minibatch training loss = 4.09e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 2.47e+05 and relative error of 0.62
# Iteration 60: with minibatch training loss = 5.32e+04 and relative error of 0.52
# Iteration 80: with minibatch training loss = 3.09e+05 and relative error of 0.4
# Iteration 100: with minibatch training loss = 1.52e+05 and relative error of 0.7
# Epoch 7, Overall loss = 2.2e+05 and relative error of 0.759
# Validation
# Epoch 1, Overall loss = 1.59e+05 and relative error of 0.636
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.42e+05 and relative error of 0.75
# Iteration 20: with minibatch training loss = 4.93e+05 and relative error of 0.63
# Iteration 40: with minibatch training loss = 7.77e+04 and relative error of 0.85
# Iteration 60: with minibatch training loss = 1.38e+05 and relative error of 0.94
# Iteration 80: with minibatch training loss = 8.63e+04 and relative error of 0.36
# Iteration 100: with minibatch training loss = 1.86e+05 and relative error of 0.55
# Epoch 8, Overall loss = 1.81e+05 and relative error of 0.676
# Validation
# Epoch 1, Overall loss = 1.52e+05 and relative error of 0.653
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.28e+05 and relative error of 0.88
# Iteration 20: with minibatch training loss = 1.15e+05 and relative error of 0.66
# Iteration 40: with minibatch training loss = 1.29e+05 and relative error of 0.37
# Iteration 60: with minibatch training loss = 1.67e+05 and relative error of 0.58
# Iteration 80: with minibatch training loss = 9.46e+04 and relative error of 0.37
# Iteration 100: with minibatch training loss = 2.19e+05 and relative error of 0.62
# Epoch 9, Overall loss = 1.7e+05 and relative error of 0.644
# Validation
# Epoch 1, Overall loss = 1.93e+05 and relative error of 0.678
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.5e+05 and relative error of 0.41
# Iteration 20: with minibatch training loss = 4.82e+04 and relative error of 0.6
# Iteration 40: with minibatch training loss = 1e+05 and relative error of 0.9
# Iteration 60: with minibatch training loss = 2.29e+05 and relative error of 0.72
# Iteration 80: with minibatch training loss = 1.55e+05 and relative error of 0.5
# Iteration 100: with minibatch training loss = 1.48e+05 and relative error of 0.92
# Epoch 10, Overall loss = 1.62e+05 and relative error of 0.631
# Validation
# Epoch 1, Overall loss = 1.51e+05 and relative error of 0.764
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.19e+05 and relative error of 1.1
# Iteration 20: with minibatch training loss = 3.07e+05 and relative error of 0.44
# Iteration 40: with minibatch training loss = 1.06e+05 and relative error of 0.73
# Iteration 60: with minibatch training loss = 5.93e+04 and relative error of 0.5
# Iteration 80: with minibatch training loss = 1.51e+05 and relative error of 1.3
# Iteration 100: with minibatch training loss = 7.81e+04 and relative error of 0.66
# Epoch 11, Overall loss = 1.62e+05 and relative error of 0.596
# Validation
# Epoch 1, Overall loss = 1.38e+05 and relative error of 0.625
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 6.64e+04 and relative error of 0.39
# Iteration 20: with minibatch training loss = 2.18e+05 and relative error of 0.35
# Iteration 40: with minibatch training loss = 1.51e+05 and relative error of 1.1
# Iteration 60: with minibatch training loss = 1.75e+05 and relative error of 0.6
# Iteration 80: with minibatch training loss = 8.66e+04 and relative error of 0.64
# Iteration 100: with minibatch training loss = 1.33e+05 and relative error of 0.66
# Epoch 12, Overall loss = 1.67e+05 and relative error of 0.591
# Validation
# Epoch 1, Overall loss = 2.64e+05 and relative error of 0.532
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.27e+05 and relative error of 0.58
# Iteration 20: with minibatch training loss = 1.56e+05 and relative error of 0.56
# Iteration 40: with minibatch training loss = 5.45e+04 and relative error of 0.62
# Iteration 60: with minibatch training loss = 1.37e+05 and relative error of 0.52
# Iteration 80: with minibatch training loss = 7.67e+04 and relative error of 0.73
# Iteration 100: with minibatch training loss = 1.37e+05 and relative error of 0.45
# Epoch 13, Overall loss = 1.56e+05 and relative error of 0.586
# Validation
# Epoch 1, Overall loss = 1.49e+05 and relative error of 0.466
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.21e+05 and relative error of 0.4
# Iteration 20: with minibatch training loss = 4.23e+05 and relative error of 0.75
# Iteration 40: with minibatch training loss = 1.22e+05 and relative error of 0.8
# Iteration 60: with minibatch training loss = 1.43e+05 and relative error of 0.51
# Iteration 80: with minibatch training loss = 9.71e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 1.51e+05 and relative error of 0.92
# Epoch 14, Overall loss = 1.63e+05 and relative error of 0.586
# Validation
# Epoch 1, Overall loss = 1.68e+05 and relative error of 0.579
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 3.38e+05 and relative error of 0.52
# Iteration 20: with minibatch training loss = 1.53e+05 and relative error of 0.73
# Iteration 40: with minibatch training loss = 1.46e+05 and relative error of 0.69
# Iteration 60: with minibatch training loss = 5.72e+04 and relative error of 1.1
# Iteration 80: with minibatch training loss = 8.94e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 1.71e+05 and relative error of 0.55
# Epoch 15, Overall loss = 1.47e+05 and relative error of 0.545
# Validation
# Epoch 1, Overall loss = 1.61e+05 and relative error of 0.63
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 8.47e+04 and relative error of 0.67
# Iteration 20: with minibatch training loss = 1.22e+05 and relative error of 0.53
# Iteration 40: with minibatch training loss = 1.45e+05 and relative error of 0.28
# Iteration 60: with minibatch training loss = 1.68e+05 and relative error of 0.64
# Iteration 80: with minibatch training loss = 1.07e+05 and relative error of 0.28
# Iteration 100: with minibatch training loss = 1.22e+05 and relative error of 0.67
# Epoch 16, Overall loss = 1.37e+05 and relative error of 0.523
# Validation
# Epoch 1, Overall loss = 1.48e+05 and relative error of 0.565
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.26e+05 and relative error of 0.84
# Iteration 20: with minibatch training loss = 3.87e+05 and relative error of 0.34
# Iteration 40: with minibatch training loss = 1e+05 and relative error of 0.86
# Iteration 60: with minibatch training loss = 3.14e+05 and relative error of 0.46
# Iteration 80: with minibatch training loss = 1.03e+05 and relative error of 0.53
# Iteration 100: with minibatch training loss = 2.77e+05 and relative error of 0.48
# Epoch 17, Overall loss = 1.31e+05 and relative error of 0.52
# Validation
# Epoch 1, Overall loss = 1.27e+05 and relative error of 0.409
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 6.88e+04 and relative error of 0.3
# Iteration 20: with minibatch training loss = 1.42e+05 and relative error of 0.58
# Iteration 40: with minibatch training loss = 1.44e+05 and relative error of 0.42
# Iteration 60: with minibatch training loss = 1.43e+05 and relative error of 0.51
# Iteration 80: with minibatch training loss = 8.21e+04 and relative error of 0.45
# Iteration 100: with minibatch training loss = 1.05e+05 and relative error of 0.35
# Epoch 18, Overall loss = 1.2e+05 and relative error of 0.497
# Validation
# Epoch 1, Overall loss = 1.37e+05 and relative error of 0.595
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.06e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 1.02e+05 and relative error of 0.56
# Iteration 40: with minibatch training loss = 1.86e+05 and relative error of 0.47
# Iteration 60: with minibatch training loss = 1.39e+05 and relative error of 0.5
# Iteration 80: with minibatch training loss = 1.65e+05 and relative error of 0.44
# Iteration 100: with minibatch training loss = 1.46e+05 and relative error of 0.5
# Epoch 19, Overall loss = 1.36e+05 and relative error of 0.521
# Validation
# Epoch 1, Overall loss = 2.66e+05 and relative error of 0.823
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 2.74e+05 and relative error of 0.76
# Iteration 20: with minibatch training loss = 1.9e+05 and relative error of 0.66
# Iteration 40: with minibatch training loss = 1.02e+05 and relative error of 0.63
# Iteration 60: with minibatch training loss = 8.65e+04 and relative error of 0.5
# Iteration 80: with minibatch training loss = 1.55e+05 and relative error of 0.41
# Iteration 100: with minibatch training loss = 1.31e+05 and relative error of 0.71
# Epoch 20, Overall loss = 1.25e+05 and relative error of 0.513
# Validation
# Epoch 1, Overall loss = 1.25e+05 and relative error of 0.5
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.2e+05 and relative error of 0.6
# Iteration 20: with minibatch training loss = 9.84e+04 and relative error of 0.34
# Iteration 40: with minibatch training loss = 1.47e+05 and relative error of 0.59
# Iteration 60: with minibatch training loss = 1.76e+05 and relative error of 0.37
# Iteration 80: with minibatch training loss = 1.36e+05 and relative error of 0.56
# Iteration 100: with minibatch training loss = 3.74e+04 and relative error of 0.41
# Epoch 21, Overall loss = 1.16e+05 and relative error of 0.487
# Validation
# Epoch 1, Overall loss = 1.18e+05 and relative error of 0.396
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 4.82e+04 and relative error of 0.47
# Iteration 20: with minibatch training loss = 3.26e+05 and relative error of 0.55
# Iteration 40: with minibatch training loss = 1.34e+05 and relative error of 0.48
# Iteration 60: with minibatch training loss = 8.88e+04 and relative error of 0.49
# Iteration 80: with minibatch training loss = 1.25e+05 and relative error of 0.43
# Iteration 100: with minibatch training loss = 1.3e+05 and relative error of 0.5
# Epoch 22, Overall loss = 1.15e+05 and relative error of 0.477
# Validation
# Epoch 1, Overall loss = 1.35e+05 and relative error of 0.504
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.69e+05 and relative error of 0.68
# Iteration 20: with minibatch training loss = 1.97e+05 and relative error of 0.44
# Iteration 40: with minibatch training loss = 1.36e+05 and relative error of 0.65
# Iteration 60: with minibatch training loss = 1.43e+05 and relative error of 0.37
# Iteration 80: with minibatch training loss = 1.41e+05 and relative error of 0.33
# Iteration 100: with minibatch training loss = 1.44e+05 and relative error of 0.54
# Epoch 23, Overall loss = 1.14e+05 and relative error of 0.492
# Validation
# Epoch 1, Overall loss = 2.01e+05 and relative error of 0.659
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 9.28e+04 and relative error of 0.97
# Iteration 20: with minibatch training loss = 2.14e+05 and relative error of 0.58
# Iteration 40: with minibatch training loss = 1.16e+05 and relative error of 0.63
# Iteration 60: with minibatch training loss = 4.21e+04 and relative error of 0.52
# Iteration 80: with minibatch training loss = 1.62e+05 and relative error of 0.83
# Iteration 100: with minibatch training loss = 8.87e+04 and relative error of 0.38
# Epoch 24, Overall loss = 1.25e+05 and relative error of 0.484
# Validation
# Epoch 1, Overall loss = 1.13e+05 and relative error of 0.409
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 5.69e+04 and relative error of 0.38
# Iteration 20: with minibatch training loss = 1.55e+05 and relative error of 0.47
# Iteration 40: with minibatch training loss = 6.25e+04 and relative error of 0.39
# Iteration 60: with minibatch training loss = 1.37e+05 and relative error of 0.42
# Iteration 80: with minibatch training loss = 1.25e+05 and relative error of 0.41
# Iteration 100: with minibatch training loss = 3.43e+04 and relative error of 0.44
# Epoch 25, Overall loss = 1.08e+05 and relative error of 0.447
# Validation
# Epoch 1, Overall loss = 1.65e+05 and relative error of 0.38
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 9.51e+04 and relative error of 0.29
# Iteration 20: with minibatch training loss = 4.26e+04 and relative error of 0.43
# Iteration 40: with minibatch training loss = 2.04e+05 and relative error of 0.62
# Iteration 60: with minibatch training loss = 8.1e+04 and relative error of 0.48
# Iteration 80: with minibatch training loss = 9.19e+04 and relative error of 0.31
# Iteration 100: with minibatch training loss = 4.23e+04 and relative error of 0.36
# Epoch 26, Overall loss = 1.19e+05 and relative error of 0.453
# Validation
# Epoch 1, Overall loss = 1.41e+05 and relative error of 0.346
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.14e+05 and relative error of 0.42
# Iteration 20: with minibatch training loss = 1.14e+05 and relative error of 0.54
# Iteration 40: with minibatch training loss = 7.95e+04 and relative error of 0.51
# Iteration 60: with minibatch training loss = 5e+04 and relative error of 0.34
# Iteration 80: with minibatch training loss = 1.89e+05 and relative error of 0.55
# Iteration 100: with minibatch training loss = 1.41e+05 and relative error of 0.49
# Epoch 27, Overall loss = 1.07e+05 and relative error of 0.454
# Validation
# Epoch 1, Overall loss = 1.12e+05 and relative error of 0.468
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.27e+05 and relative error of 0.39
# Iteration 20: with minibatch training loss = 1.26e+05 and relative error of 0.51
# Iteration 40: with minibatch training loss = 9.91e+04 and relative error of 0.51
# Iteration 60: with minibatch training loss = 1.28e+05 and relative error of 0.36
# Iteration 80: with minibatch training loss = 8.53e+04 and relative error of 0.4
# Iteration 100: with minibatch training loss = 4.39e+04 and relative error of 0.54
# Epoch 28, Overall loss = 9.31e+04 and relative error of 0.437
# Validation
# Epoch 1, Overall loss = 1.11e+05 and relative error of 0.435
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 8.56e+04 and relative error of 0.33
# Iteration 20: with minibatch training loss = 4.31e+04 and relative error of 0.54
# Iteration 40: with minibatch training loss = 1.82e+05 and relative error of 0.43
# Iteration 60: with minibatch training loss = 1.49e+05 and relative error of 0.35
# Iteration 80: with minibatch training loss = 1.01e+05 and relative error of 0.36
# Iteration 100: with minibatch training loss = 1.32e+05 and relative error of 0.37
# Epoch 29, Overall loss = 9.95e+04 and relative error of 0.436
# Validation
# Epoch 1, Overall loss = 1.19e+05 and relative error of 0.373
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 6.33e+04 and relative error of 0.26
# Iteration 20: with minibatch training loss = 9.03e+04 and relative error of 0.55
# Iteration 40: with minibatch training loss = 1.33e+05 and relative error of 0.4
# Iteration 60: with minibatch training loss = 2.02e+05 and relative error of 0.41
# Iteration 80: with minibatch training loss = 6.83e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 1.35e+05 and relative error of 0.44
# Epoch 30, Overall loss = 1.05e+05 and relative error of 0.44
# Validation
# Epoch 1, Overall loss = 1.53e+05 and relative error of 0.626
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 6.76e+04 and relative error of 0.55
# Iteration 20: with minibatch training loss = 1.69e+05 and relative error of 0.28
# Iteration 40: with minibatch training loss = 8.65e+04 and relative error of 0.46
# Iteration 60: with minibatch training loss = 5.02e+04 and relative error of 0.33
# Iteration 80: with minibatch training loss = 9.51e+04 and relative error of 0.28
# Iteration 100: with minibatch training loss = 1.06e+05 and relative error of 0.28
# Epoch 31, Overall loss = 8.63e+04 and relative error of 0.436
# Validation
# Epoch 1, Overall loss = 1.12e+05 and relative error of 0.414
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.15e+05 and relative error of 0.24
# Iteration 20: with minibatch training loss = 1.19e+05 and relative error of 0.42
# Iteration 40: with minibatch training loss = 9.12e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 8.82e+04 and relative error of 0.29
# Iteration 80: with minibatch training loss = 1.01e+05 and relative error of 0.35
# Iteration 100: with minibatch training loss = 5.61e+04 and relative error of 0.49
# Epoch 32, Overall loss = 9.22e+04 and relative error of 0.412
# Validation
# Epoch 1, Overall loss = 1.06e+05 and relative error of 0.373
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 1.22e+05 and relative error of 0.58
# Iteration 20: with minibatch training loss = 5.63e+04 and relative error of 0.66
# Iteration 40: with minibatch training loss = 1.5e+05 and relative error of 0.27
# Iteration 60: with minibatch training loss = 6.67e+04 and relative error of 0.35
# Iteration 80: with minibatch training loss = 8.49e+04 and relative error of 0.44
# Iteration 100: with minibatch training loss = 5.11e+04 and relative error of 0.29
# Epoch 33, Overall loss = 7.95e+04 and relative error of 0.419
# Validation
# Epoch 1, Overall loss = 1.3e+05 and relative error of 0.409
# For image resolution 40*40
# Training
# Iteration 0: with minibatch training loss = 9.11e+04 and relative error of 0.57
# Iteration 20: with minibatch training loss = 1.76e+05 and relative error of 0.56
# Iteration 40: with minibatch training loss = 6.4e+04 and relative error of 0.27
# Iteration 60: with minibatch training loss = 5.49e+04 and relative error of 0.53
# ...
# Iteration 100: with minibatch training loss = 1.18e+05 and relative error of 0.72
# Epoch 16, Overall loss = 9.15e+04 and relative error of 0.554
# Validation
# Epoch 1, Overall loss = 1.62e+05 and relative error of 0.764
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 7.93e+04 and relative error of 0.45
# Iteration 20: with minibatch training loss = 8.59e+04 and relative error of 0.78
# Iteration 40: with minibatch training loss = 8.06e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 1.31e+05 and relative error of 0.45
# Iteration 80: with minibatch training loss = 9.8e+04 and relative error of 0.72
# Iteration 100: with minibatch training loss = 8.32e+04 and relative error of 0.61
# Epoch 17, Overall loss = 9.03e+04 and relative error of 0.562
# Validation
# Epoch 1, Overall loss = 1.3e+05 and relative error of 0.47
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 6.77e+04 and relative error of 0.37
# Iteration 20: with minibatch training loss = 1.23e+05 and relative error of 0.46
# Iteration 40: with minibatch training loss = 9.84e+04 and relative error of 0.5
# Iteration 60: with minibatch training loss = 5.69e+04 and relative error of 0.49
# Iteration 80: with minibatch training loss = 7.55e+04 and relative error of 0.67
# Iteration 100: with minibatch training loss = 3.19e+04 and relative error of 0.47
# Epoch 18, Overall loss = 7.89e+04 and relative error of 0.527
# Validation
# Epoch 1, Overall loss = 1.32e+05 and relative error of 0.445
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 9.55e+04 and relative error of 0.34
# Iteration 20: with minibatch training loss = 7.45e+04 and relative error of 0.49
# Iteration 40: with minibatch training loss = 4.52e+04 and relative error of 0.42
# Iteration 60: with minibatch training loss = 5.5e+04 and relative error of 0.52
# Iteration 80: with minibatch training loss = 6.38e+04 and relative error of 0.38
# Iteration 100: with minibatch training loss = 4.19e+04 and relative error of 0.67
# Epoch 19, Overall loss = 6.84e+04 and relative error of 0.497
# Validation
# Epoch 1, Overall loss = 1.59e+05 and relative error of 0.525
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 8.34e+04 and relative error of 0.55
# Iteration 20: with minibatch training loss = 5.7e+04 and relative error of 0.75
# Iteration 40: with minibatch training loss = 7.81e+04 and relative error of 0.47
# Iteration 60: with minibatch training loss = 7.13e+04 and relative error of 0.43
# Iteration 80: with minibatch training loss = 8.51e+04 and relative error of 0.37
# Iteration 100: with minibatch training loss = 5.56e+04 and relative error of 0.45
# Epoch 20, Overall loss = 6.67e+04 and relative error of 0.479
# Validation
# Epoch 1, Overall loss = 1.31e+05 and relative error of 0.44
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 3.49e+04 and relative error of 0.58
# Iteration 20: with minibatch training loss = 5.09e+04 and relative error of 0.62
# Iteration 40: with minibatch training loss = 5.63e+04 and relative error of 0.42
# Iteration 60: with minibatch training loss = 9.32e+04 and relative error of 0.64
# Iteration 80: with minibatch training loss = 3.5e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 6.43e+04 and relative error of 0.39
# Epoch 21, Overall loss = 6.23e+04 and relative error of 0.458
# Validation
# Epoch 1, Overall loss = 1.35e+05 and relative error of 0.446
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 5.12e+04 and relative error of 0.39
# Iteration 20: with minibatch training loss = 3.34e+04 and relative error of 0.37
# Iteration 40: with minibatch training loss = 5.2e+04 and relative error of 0.52
# Iteration 60: with minibatch training loss = 6.6e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 5.93e+04 and relative error of 0.66
# Iteration 100: with minibatch training loss = 2.91e+04 and relative error of 0.42
# Epoch 22, Overall loss = 5.67e+04 and relative error of 0.451
# Validation
# Epoch 1, Overall loss = 1.32e+05 and relative error of 0.476
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 5.04e+04 and relative error of 0.42
# Iteration 20: with minibatch training loss = 6.81e+04 and relative error of 0.31
# Iteration 40: with minibatch training loss = 5.85e+04 and relative error of 0.73
# Iteration 60: with minibatch training loss = 7.11e+04 and relative error of 0.54
# Iteration 80: with minibatch training loss = 4.51e+04 and relative error of 0.35
# Iteration 100: with minibatch training loss = 2.16e+04 and relative error of 0.37
# Epoch 23, Overall loss = 5.44e+04 and relative error of 0.44
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.462
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 5.54e+04 and relative error of 0.48
# Iteration 20: with minibatch training loss = 9.3e+04 and relative error of 0.54
# Iteration 40: with minibatch training loss = 5.53e+04 and relative error of 0.49
# Iteration 60: with minibatch training loss = 3.56e+04 and relative error of 0.28
# Iteration 80: with minibatch training loss = 5.19e+04 and relative error of 0.44
# Iteration 100: with minibatch training loss = 7.07e+04 and relative error of 0.46
# Epoch 24, Overall loss = 5.99e+04 and relative error of 0.435
# Validation
# Epoch 1, Overall loss = 1.46e+05 and relative error of 0.538
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 4.52e+04 and relative error of 0.7
# Iteration 20: with minibatch training loss = 7.61e+04 and relative error of 0.49
# Iteration 40: with minibatch training loss = 3.09e+04 and relative error of 0.36
# Iteration 60: with minibatch training loss = 3.83e+04 and relative error of 0.43
# Iteration 80: with minibatch training loss = 6.52e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 2.75e+04 and relative error of 0.33
# Epoch 25, Overall loss = 5.13e+04 and relative error of 0.422
# Validation
# Epoch 1, Overall loss = 1.34e+05 and relative error of 0.372
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 4.39e+04 and relative error of 0.54
# Iteration 20: with minibatch training loss = 5.42e+04 and relative error of 0.29
# Iteration 40: with minibatch training loss = 4.17e+04 and relative error of 0.55
# Iteration 60: with minibatch training loss = 3.9e+04 and relative error of 0.25
# Iteration 80: with minibatch training loss = 2.6e+04 and relative error of 0.39
# Iteration 100: with minibatch training loss = 5.07e+04 and relative error of 0.37
# Epoch 26, Overall loss = 4.92e+04 and relative error of 0.412
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.366
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 6.8e+04 and relative error of 0.39
# Iteration 20: with minibatch training loss = 2.86e+04 and relative error of 0.44
# Iteration 40: with minibatch training loss = 4.96e+04 and relative error of 0.42
# Iteration 60: with minibatch training loss = 3.47e+04 and relative error of 0.33
# Iteration 80: with minibatch training loss = 5.27e+04 and relative error of 0.69
# Iteration 100: with minibatch training loss = 7.66e+04 and relative error of 0.26
# Epoch 27, Overall loss = 4.95e+04 and relative error of 0.396
# Validation
# Epoch 1, Overall loss = 1.38e+05 and relative error of 0.581
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 3.7e+04 and relative error of 0.35
# Iteration 20: with minibatch training loss = 3.6e+04 and relative error of 0.41
# Iteration 40: with minibatch training loss = 3.72e+04 and relative error of 0.36
# Iteration 60: with minibatch training loss = 3.35e+04 and relative error of 0.46
# Iteration 80: with minibatch training loss = 6.2e+04 and relative error of 0.39
# Iteration 100: with minibatch training loss = 3.58e+04 and relative error of 0.29
# Epoch 28, Overall loss = 4.71e+04 and relative error of 0.408
# Validation
# Epoch 1, Overall loss = 1.5e+05 and relative error of 0.376
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 7.04e+04 and relative error of 0.4
# Iteration 20: with minibatch training loss = 2.97e+04 and relative error of 0.3
# Iteration 40: with minibatch training loss = 5.94e+04 and relative error of 0.4
# Iteration 60: with minibatch training loss = 7.33e+04 and relative error of 0.59
# Iteration 80: with minibatch training loss = 6.61e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 6.57e+04 and relative error of 0.19
# Epoch 29, Overall loss = 4.85e+04 and relative error of 0.393
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.391
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 1.71e+04 and relative error of 0.41
# Iteration 20: with minibatch training loss = 5.13e+04 and relative error of 0.31
# Iteration 40: with minibatch training loss = 5.42e+04 and relative error of 0.32
# Iteration 60: with minibatch training loss = 4.39e+04 and relative error of 0.35
# Iteration 80: with minibatch training loss = 6.43e+04 and relative error of 0.38
# Iteration 100: with minibatch training loss = 3.6e+04 and relative error of 0.41
# Epoch 30, Overall loss = 4.5e+04 and relative error of 0.392
# Validation
# Epoch 1, Overall loss = 1.35e+05 and relative error of 0.424
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 2.88e+04 and relative error of 0.31
# Iteration 20: with minibatch training loss = 2.28e+04 and relative error of 0.26
# Iteration 40: with minibatch training loss = 2.62e+04 and relative error of 0.31
# Iteration 60: with minibatch training loss = 5.81e+04 and relative error of 0.35
# Iteration 80: with minibatch training loss = 2.94e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 4.55e+04 and relative error of 0.35
# Epoch 31, Overall loss = 4.29e+04 and relative error of 0.378
# Validation
# Epoch 1, Overall loss = 1.39e+05 and relative error of 0.438
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 4.38e+04 and relative error of 0.36
# Iteration 20: with minibatch training loss = 3.87e+04 and relative error of 0.51
# Iteration 40: with minibatch training loss = 3.63e+04 and relative error of 0.31
# Iteration 60: with minibatch training loss = 4.1e+04 and relative error of 0.42
# Iteration 80: with minibatch training loss = 3.89e+04 and relative error of 0.21
# Iteration 100: with minibatch training loss = 6.5e+04 and relative error of 0.38
# Epoch 32, Overall loss = 4.05e+04 and relative error of 0.347
# Validation
# Epoch 1, Overall loss = 1.31e+05 and relative error of 0.407
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 5.66e+04 and relative error of 0.34
# Iteration 20: with minibatch training loss = 3.88e+04 and relative error of 0.44
# Iteration 40: with minibatch training loss = 4.96e+04 and relative error of 0.32
# Iteration 60: with minibatch training loss = 3.75e+04 and relative error of 0.39
# Iteration 80: with minibatch training loss = 2.55e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 4.2e+04 and relative error of 0.24
# Epoch 33, Overall loss = 4.22e+04 and relative error of 0.358
# Validation
# Epoch 1, Overall loss = 1.35e+05 and relative error of 0.356
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 2.66e+04 and relative error of 0.27
# Iteration 20: with minibatch training loss = 5.26e+04 and relative error of 0.29
# Iteration 40: with minibatch training loss = 5.48e+04 and relative error of 0.4
# Iteration 60: with minibatch training loss = 4.58e+04 and relative error of 0.32
# Iteration 80: with minibatch training loss = 3.99e+04 and relative error of 0.44
# Iteration 100: with minibatch training loss = 2.57e+04 and relative error of 0.22
# Epoch 34, Overall loss = 4.46e+04 and relative error of 0.359
# Validation
# Epoch 1, Overall loss = 1.4e+05 and relative error of 0.377
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 4.72e+04 and relative error of 0.25
# Iteration 20: with minibatch training loss = 2.11e+04 and relative error of 0.32
# Iteration 40: with minibatch training loss = 6.22e+04 and relative error of 0.34
# Iteration 60: with minibatch training loss = 2.34e+04 and relative error of 0.37
# Iteration 80: with minibatch training loss = 4.79e+04 and relative error of 0.4
# Iteration 100: with minibatch training loss = 2.94e+04 and relative error of 0.29
# Epoch 35, Overall loss = 3.85e+04 and relative error of 0.35
# Validation
# Epoch 1, Overall loss = 1.29e+05 and relative error of 0.384
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 2.02e+04 and relative error of 0.28
# Iteration 20: with minibatch training loss = 6.78e+04 and relative error of 0.47
# Iteration 40: with minibatch training loss = 2.99e+04 and relative error of 0.39
# Iteration 60: with minibatch training loss = 3.55e+04 and relative error of 0.52
# Iteration 80: with minibatch training loss = 3.34e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 6.15e+04 and relative error of 0.25
# Epoch 36, Overall loss = 4.52e+04 and relative error of 0.351
# Validation
# Epoch 1, Overall loss = 1.26e+05 and relative error of 0.38
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 2.01e+04 and relative error of 0.33
# Iteration 20: with minibatch training loss = 2.19e+04 and relative error of 0.2
# Iteration 40: with minibatch training loss = 3.93e+04 and relative error of 0.43
# Iteration 60: with minibatch training loss = 4.24e+04 and relative error of 0.41
# Iteration 80: with minibatch training loss = 2.9e+04 and relative error of 0.41
# Iteration 100: with minibatch training loss = 7.03e+04 and relative error of 0.34
# Epoch 37, Overall loss = 4.42e+04 and relative error of 0.352
# Validation
# Epoch 1, Overall loss = 1.31e+05 and relative error of 0.366
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 1.98e+04 and relative error of 0.43
# Iteration 20: with minibatch training loss = 5.6e+04 and relative error of 0.35
# Iteration 40: with minibatch training loss = 2.76e+04 and relative error of 0.29
# Iteration 60: with minibatch training loss = 2.91e+04 and relative error of 0.26
# Iteration 80: with minibatch training loss = 3.56e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 2.38e+04 and relative error of 0.22
# Epoch 38, Overall loss = 3.92e+04 and relative error of 0.339
# Validation
# Epoch 1, Overall loss = 1.27e+05 and relative error of 0.4
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 3.08e+04 and relative error of 0.31
# Iteration 20: with minibatch training loss = 2.66e+04 and relative error of 0.4
# Iteration 40: with minibatch training loss = 3.34e+04 and relative error of 0.29
# Iteration 60: with minibatch training loss = 1.56e+04 and relative error of 0.44
# Iteration 80: with minibatch training loss = 3.29e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 3.75e+04 and relative error of 0.17
# Epoch 39, Overall loss = 3.68e+04 and relative error of 0.329
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.424
# For image resolution 128*128
# Training
# Iteration 0: with minibatch training loss = 4.64e+04 and relative error of 0.42
# Iteration 20: with minibatch training loss = 2.49e+04 and relative error of 0.41
# Iteration 40: with minibatch training loss = 4.44e+04 and relative error of 0.24
# Iteration 60: with minibatch training loss = 3.4e+04 and relative error of 0.34
# Iteration 80: with minibatch training loss = 4.03e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 4.19e+04 and relative error of 0.28
# Epoch 40, Overall loss = 3.76e+04 and relative error of 0.32
# Validation
# Epoch 1, Overall loss = 1.32e+05 and relative error of 0.45

# %%
np.save(os.path.join(npy_folder,"train_loss.npy"),train_loss_hist)
np.save(os.path.join(npy_folder,"train_error.npy"),train_error_hist)
np.save(os.path.join(npy_folder,"val_loss.npy"),val_loss_hist)
np.save(os.path.join(npy_folder,"val_error.npy"),val_error_hist)

# # Saving the model
# saver = tf.train.Saver()
# save_path = saver.save(sess, "G:\\Google Drive\\solar_research\\cnn7533.ckpt")
# print("Model saved in file: %s" % save_path)

# %%
train_loss_hist = np.load(os.path.join(npy_folder,"train_loss.npy"))
train_error_hist = np.load(os.path.join(npy_folder,"train_error.npy"))
val_loss_hist = np.load(os.path.join(npy_folder,"val_loss.npy"))
val_error_hist = np.load(os.path.join(npy_folder,"val_error.npy"))

# %%
# loading the model
saver = tf.train.Saver()
save_path = "cnn_7533.ckpt"
saver.restore(sess, save_path)

# %%
# Plotting final results
# plot training loss history
# plt.boxplot(train_loss_hist[:,30:],label= 'training loss history')
plt.boxplot(val_loss_hist[:,30:].transpose(),labels=output_img_len)
plt.grid(True)
plt.xlabel('Input image side length')
plt.ylabel('Loss')
plt.ticklabel_format(axis='y', style='sci', scilimits=(-2,2))

plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# Plotting final results
# plot training loss history
plt.plot(train_loss_hist[12,:],label= 'training loss history')
plt.plot(val_loss_hist[12,:],label= 'validation loss history')
plt.yscale('log')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('training loss')
plt.legend()
plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# plot relative error history
plt.plot(train_error_hist[:,39], label='training relative error')
plt.plot(val_error_hist[:,39], label='validation relative error')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('relative error')
plt.legend()
plt.savefig('relative_error.png', bbox_inches='tight')
plt.show()

# %%
idx1 = np.arange(0,491) # a sunny day at 12-20-16
idx2 = np.arange(2730,3145) # a cloudy day at 1-1-17
idx3 = np.arange(5420,5843) # a rainy  day at 1-8-17

idx = np.concatenate((idx1,idx2,idx3))

print(idx.shape)

# %%
idx= idx
feed_dict = {x_var: images[idx],y_var: pv_out[idx],is_training: False}

mse,pred_y_value = sess.run([mean_loss,pred_y_var], feed_dict=feed_dict)

plt.plot(pv_out[idx], label='actual pv output')
plt.plot(pred_y_value, label='predicted pv output')
plt.grid(True)
plt.xlabel('image index')
plt.ylabel('panel output (Btu/hr)')
plt.legend()
plt.savefig('predicted_and_actual_output.png', bbox_inches='tight')
plt.show()

print('RMSE: ', np.sqrt(mse))
