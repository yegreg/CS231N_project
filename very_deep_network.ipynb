# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# Loading in and dividing data
# reads in data
images = np.load("images.npy")
pv_out = np.load("pv_outputs.npy")


images_test = images[:1400]
pv_test = pv_out[:1400]
images = images[1400:]
pv_out = pv_out[1400:]

# randomly divides into a training set and a validation set
num_imgs = images.shape[0]
indices = np.arange(num_imgs)
np.random.shuffle(indices)
X_train, X_val = images[indices[:int(0.8 * num_imgs)]], images[indices[int(0.8 * num_imgs):]]
y_train, y_val = pv_out[indices[:int(0.8 * num_imgs)]], pv_out[indices[int(0.8 * num_imgs):]]

# %%
# The model
def cnn_model_depth8_wider(X, y, is_training):
    # CBP sandwich 1
    conv1 = tf.layers.conv2d(
        inputs=X,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn1 = tf.layers.batch_normalization(inputs=conv1, axis=1)
    conv2 = tf.layers.conv2d(
        inputs=bn1,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn2 = tf.layers.batch_normalization(inputs=conv2, axis=1)
    pool1 = tf.layers.max_pooling2d(inputs=bn2, pool_size=[2, 2], strides=2)
    conv3 = tf.layers.conv2d(
        inputs=pool1,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    conv4 = tf.layers.conv2d(
        inputs=bn3,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn4 = tf.layers.batch_normalization(inputs=conv4, axis=1)
    pool2 = tf.layers.max_pooling2d(inputs=bn4, pool_size=[2, 2], strides=2)
    conv5 = tf.layers.conv2d(
        inputs=pool2,
        filters=128,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn5 = tf.layers.batch_normalization(inputs=conv5, axis=1)
    conv6 = tf.layers.conv2d(
        inputs=bn5,
        filters=128,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn6 = tf.layers.batch_normalization(inputs=conv6, axis=1)
    pool3 = tf.layers.max_pooling2d(inputs=bn6, pool_size=[2, 2], strides=2)
    conv7 = tf.layers.conv2d(
        inputs=pool3,
        filters=256,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn7 = tf.layers.batch_normalization(inputs=conv7, axis=1)
    conv8 = tf.layers.conv2d(
        inputs=bn7,
        filters=256,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn8 = tf.layers.batch_normalization(inputs=conv8, axis=1)
    # pool4 = tf.layers.max_pooling2d(inputs=bn8, pool_size=[2, 2], strides=2)
    

    
    pool4_flat = tf.reshape(bn8, [-1, 7 * 7 * 256])
    
    # Fully connected nets
    dense1 = tf.layers.dense(inputs=pool4_flat, units=1024, activation=tf.nn.relu)
    bn_dense1 = tf.layers.batch_normalization(inputs=dense1)
    dropout1 = tf.layers.dropout(
        inputs=bn_dense1, rate=0.4, training=is_training)
    dense2 = tf.layers.dense(inputs=dropout1, units=1024, activation=tf.nn.relu)
    bn_dense2 = tf.layers.batch_normalization(inputs=dense2)
    dropout2 = tf.layers.dropout(
        inputs=bn_dense2, rate=0.4, training=is_training)
    dense3 = tf.layers.dense(inputs=dropout2, units=1024, activation=tf.nn.relu)
    bn_dense3 = tf.layers.batch_normalization(inputs=dense3)
    dropout3 = tf.layers.dropout(
        inputs=bn_dense3, rate=0.4, training=is_training)
    
    regression = tf.layers.dense(inputs=dropout3, units=1)
    regression = tf.reshape(regression, [-1])
    return regression

# %%
# Run model 
def run_model(session, pred_y_var, loss_var,
              x_var,y_var,is_training, Xd, yd,
              epoch_idx=0, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    rel_err_var = tf.divide(tf.abs(tf.subtract(y_var, pred_y_var)), y_var)
    accuracy = tf.reduce_mean(rel_err_var)

    # shuffle indices
    train_indices = np.arange(Xd.shape[0])
    np.random.shuffle(train_indices)
    training_now = training is not None

    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_var, rel_err_var, accuracy]
    if training_now:
        variables[-1] = training

    # counter
    iter_cnt = 0

    # keep track of losses and accuracy
    errors = 0
    losses = []

    # make sure we iterate over the dataset once
    for i in range(int(Xd.shape[0] / batch_size)+1):
        # generate indices for the batch
        start_idx = (i * batch_size) % Xd.shape[0]
        idx = train_indices[start_idx:start_idx + batch_size]

        # create a feed dictionary for this batch
        feed_dict = {x_var: Xd[idx, :],
                     y_var: yd[idx],
                     is_training: training_now}
        # get batch size
        actual_batch_size = yd[i:i + batch_size].shape[0]

        # have tensorflow compute loss and correct predictions
        # and (if given) perform a training step
        loss, rel_err, _ = session.run(variables, feed_dict=feed_dict)

        # aggregate performance stats
        losses.append(loss * actual_batch_size)
        errors += np.sum(rel_err)

        # print every now and then
        if training_now and (iter_cnt % print_every) == 0:
            print("Iteration {0}: with minibatch training loss = {1:.3g} and relative error of {2:.2g}"
                  .format(iter_cnt, loss, np.sum(rel_err) / actual_batch_size))
        iter_cnt += 1
    total_error = errors / Xd.shape[0]
    total_loss = np.sum(losses) / Xd.shape[0]

    print("Epoch {2}, Overall loss = {0:.3g} and relative error of {1:.3g}"
          .format(total_loss, total_error, epoch_idx+1 ))

    if plot_losses:
        plt.plot(losses)
        plt.grid(True)
        plt.title('Epoch {} Loss'.format(epoch_idx + 1))
        plt.xlabel('minibatch number')
        plt.ylabel('minibatch loss')
        plt.show()

    return total_loss, total_error

# %%
# Build computational graph
tf.reset_default_graph()  # Reset computational graph

x_var = tf.placeholder(tf.float32, [None, 60, 60, 3]) # x variable
y_var = tf.placeholder(tf.float32, [None]) # y variable
is_training = tf.placeholder(tf.bool) # flag
pred_y_var = cnn_model_depth8_wider(x_var, y_var, is_training) # model in use
mean_loss = tf.losses.mean_squared_error(y_var, pred_y_var) # loss in use

# Define optimizer and optimize session parameter
# define optimizer
optimizer = tf.train.AdamOptimizer(1e-3)
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)
pass

# %%
# Train the model
# initialize all variable
num_epochs = 40
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# initialize loss and rel_err history list
train_loss_hist = []
train_error_hist = []
val_loss_hist = []
val_error_hist = []

for epoch_idx in range(num_epochs):
    print('Training')
    train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                        x_var,y_var,is_training,
                                        X_train, y_train, epoch_idx, 100, 20, train_step,False)
    print('Validation')
    val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                    x_var, y_var, is_training, X_val, y_val)
    
    train_loss_hist.append(train_loss)
    train_error_hist.append(train_error)
    val_loss_hist.append(val_loss)
    val_error_hist.append(val_error)

# Saving the model
model_name = "cnn_depth8_wider"
saver = tf.train.Saver()
save_path = saver.save(sess, model_name + ".ckpt")
print("Model saved in file: %s" % save_path)

# Saving training history
train_loss = np.array(train_loss_hist)
np.save(model_name+"_train_loss", train_loss)
train_error = np.array(train_error_hist)
np.save(model_name+"_train_error", train_error)
val_loss = np.array(val_loss_hist)
np.save(model_name+"_val_loss", val_loss)
val_error = np.array(val_error_hist)
np.save(model_name+"_val_error", val_error)
# Out:
# Training
# Iteration 0: with minibatch training loss = 4.86e+06 and relative error of 0.99
# Iteration 20: with minibatch training loss = 5.14e+06 and relative error of 26
# Iteration 40: with minibatch training loss = 2.57e+06 and relative error of 16
# Iteration 60: with minibatch training loss = 2.22e+06 and relative error of 16
# Iteration 80: with minibatch training loss = 1.86e+06 and relative error of 1
# Iteration 100: with minibatch training loss = 4.35e+05 and relative error of 4
# Epoch 1, Overall loss = 4.04e+06 and relative error of 6.45
# Validation
# Epoch 1, Overall loss = 5.33e+05 and relative error of 1.52
# Training
# Iteration 0: with minibatch training loss = 1.29e+06 and relative error of 1.6
# Iteration 20: with minibatch training loss = 5.08e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 2.77e+05 and relative error of 2.8
# Iteration 60: with minibatch training loss = 2.32e+05 and relative error of 1.1
# Iteration 80: with minibatch training loss = 3.54e+05 and relative error of 2.6
# Iteration 100: with minibatch training loss = 2.61e+05 and relative error of 1.1
# Epoch 2, Overall loss = 4.49e+05 and relative error of 1.98
# Validation
# Epoch 1, Overall loss = 2.88e+05 and relative error of 1.11
# Training
# Iteration 0: with minibatch training loss = 2.34e+05 and relative error of 0.84
# Iteration 20: with minibatch training loss = 3.88e+05 and relative error of 1.2
# Iteration 40: with minibatch training loss = 3.3e+05 and relative error of 0.88
# Iteration 60: with minibatch training loss = 3.25e+05 and relative error of 2.3
# Iteration 80: with minibatch training loss = 2.07e+05 and relative error of 1.5
# Iteration 100: with minibatch training loss = 3.28e+05 and relative error of 0.62
# Epoch 3, Overall loss = 3.17e+05 and relative error of 1.44
# Validation
# Epoch 1, Overall loss = 3.45e+05 and relative error of 1.11
# Training
# Iteration 0: with minibatch training loss = 3.92e+05 and relative error of 1.2
# Iteration 20: with minibatch training loss = 2.31e+05 and relative error of 0.92
# Iteration 40: with minibatch training loss = 2.05e+05 and relative error of 0.81
# Iteration 60: with minibatch training loss = 3.7e+05 and relative error of 0.98
# Iteration 80: with minibatch training loss = 2.82e+05 and relative error of 1.6
# Iteration 100: with minibatch training loss = 1.21e+05 and relative error of 1.3
# Epoch 4, Overall loss = 2.76e+05 and relative error of 1.23
# Validation
# Epoch 1, Overall loss = 2.09e+05 and relative error of 0.907
# Training
# Iteration 0: with minibatch training loss = 1.71e+05 and relative error of 1
# Iteration 20: with minibatch training loss = 2.74e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 3.03e+05 and relative error of 2.3
# Iteration 60: with minibatch training loss = 2.29e+05 and relative error of 0.89
# Iteration 80: with minibatch training loss = 2.48e+05 and relative error of 0.92
# Iteration 100: with minibatch training loss = 1.92e+05 and relative error of 1
# Epoch 5, Overall loss = 2.28e+05 and relative error of 1.04
# Validation
# Epoch 1, Overall loss = 1.8e+05 and relative error of 0.942
# Training
# Iteration 0: with minibatch training loss = 1.28e+05 and relative error of 0.95
# Iteration 20: with minibatch training loss = 1.79e+05 and relative error of 0.71
# Iteration 40: with minibatch training loss = 2.68e+05 and relative error of 1.6
# Iteration 60: with minibatch training loss = 1.65e+05 and relative error of 0.84
# Iteration 80: with minibatch training loss = 1.98e+05 and relative error of 0.82
# Iteration 100: with minibatch training loss = 1.78e+05 and relative error of 2.1
# Epoch 6, Overall loss = 2.06e+05 and relative error of 0.949
# Validation
# Epoch 1, Overall loss = 3.65e+05 and relative error of 1.02
# Training
# Iteration 0: with minibatch training loss = 2.83e+05 and relative error of 1.1
# Iteration 20: with minibatch training loss = 1.65e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 2.86e+05 and relative error of 1.1
# Iteration 60: with minibatch training loss = 2.51e+05 and relative error of 1
# Iteration 80: with minibatch training loss = 2.49e+05 and relative error of 0.81
# Iteration 100: with minibatch training loss = 7.54e+04 and relative error of 0.48
# Epoch 7, Overall loss = 2.13e+05 and relative error of 0.849
# Validation
# Epoch 1, Overall loss = 1.72e+05 and relative error of 0.959
# Training
# Iteration 0: with minibatch training loss = 1.51e+05 and relative error of 0.66
# Iteration 20: with minibatch training loss = 4.98e+05 and relative error of 0.48
# Iteration 40: with minibatch training loss = 3.68e+05 and relative error of 0.86
# Iteration 60: with minibatch training loss = 1.73e+05 and relative error of 0.76
# Iteration 80: with minibatch training loss = 1.98e+05 and relative error of 1.3
# Iteration 100: with minibatch training loss = 9.38e+04 and relative error of 1
# Epoch 8, Overall loss = 2.36e+05 and relative error of 0.893
# Validation
# Epoch 1, Overall loss = 1.72e+05 and relative error of 0.725
# Training
# Iteration 0: with minibatch training loss = 1.59e+05 and relative error of 0.45
# Iteration 20: with minibatch training loss = 1.6e+05 and relative error of 0.52
# Iteration 40: with minibatch training loss = 4.16e+05 and relative error of 1.4
# Iteration 60: with minibatch training loss = 3.22e+05 and relative error of 0.83
# Iteration 80: with minibatch training loss = 2.48e+05 and relative error of 0.55
# Iteration 100: with minibatch training loss = 1.15e+05 and relative error of 0.65
# Epoch 9, Overall loss = 1.91e+05 and relative error of 0.721
# Validation
# Epoch 1, Overall loss = 1.51e+05 and relative error of 0.798
# Training
# Iteration 0: with minibatch training loss = 8.85e+04 and relative error of 0.68
# Iteration 20: with minibatch training loss = 7.69e+04 and relative error of 0.51
# Iteration 40: with minibatch training loss = 1.24e+05 and relative error of 0.65
# Iteration 60: with minibatch training loss = 2.4e+05 and relative error of 0.57
# Iteration 80: with minibatch training loss = 1.42e+05 and relative error of 0.68
# Iteration 100: with minibatch training loss = 2.62e+05 and relative error of 0.37
# Epoch 10, Overall loss = 1.72e+05 and relative error of 0.686
# Validation
# Epoch 1, Overall loss = 2.03e+05 and relative error of 0.844
# Training
# Iteration 0: with minibatch training loss = 2.39e+05 and relative error of 0.33
# Iteration 20: with minibatch training loss = 2.43e+05 and relative error of 0.48
# Iteration 40: with minibatch training loss = 2.78e+05 and relative error of 0.48
# Iteration 60: with minibatch training loss = 4.99e+05 and relative error of 0.57
# Iteration 80: with minibatch training loss = 2.42e+05 and relative error of 0.55
# Iteration 100: with minibatch training loss = 9.47e+04 and relative error of 0.91
# Epoch 11, Overall loss = 2.12e+05 and relative error of 0.729
# Validation
# Epoch 1, Overall loss = 2.44e+05 and relative error of 0.707
# Training
# Iteration 0: with minibatch training loss = 1.32e+05 and relative error of 0.37
# Iteration 20: with minibatch training loss = 1.62e+05 and relative error of 0.83
# Iteration 40: with minibatch training loss = 1.41e+05 and relative error of 0.82
# Iteration 60: with minibatch training loss = 2.94e+05 and relative error of 0.88
# Iteration 80: with minibatch training loss = 1.78e+05 and relative error of 0.54
# Iteration 100: with minibatch training loss = 1.59e+05 and relative error of 0.76
# Epoch 12, Overall loss = 1.66e+05 and relative error of 0.684
# Validation
# Epoch 1, Overall loss = 1.58e+05 and relative error of 0.76
# Training
# Iteration 0: with minibatch training loss = 1.3e+05 and relative error of 0.37
# Iteration 20: with minibatch training loss = 1.34e+05 and relative error of 0.84
# Iteration 40: with minibatch training loss = 9.72e+04 and relative error of 0.9
# Iteration 60: with minibatch training loss = 1.15e+05 and relative error of 0.38
# Iteration 80: with minibatch training loss = 1.13e+05 and relative error of 0.81
# Iteration 100: with minibatch training loss = 1.67e+05 and relative error of 1
# Epoch 13, Overall loss = 1.54e+05 and relative error of 0.643
# Validation
# Epoch 1, Overall loss = 1.73e+05 and relative error of 0.987
# Training
# Iteration 0: with minibatch training loss = 1.59e+05 and relative error of 0.65
# Iteration 20: with minibatch training loss = 7.33e+04 and relative error of 0.34
# Iteration 40: with minibatch training loss = 1.22e+05 and relative error of 1.1
# Iteration 60: with minibatch training loss = 1.05e+05 and relative error of 0.55
# Iteration 80: with minibatch training loss = 1.24e+05 and relative error of 0.53
# Iteration 100: with minibatch training loss = 1.3e+05 and relative error of 0.99
# Epoch 14, Overall loss = 1.49e+05 and relative error of 0.641
# Validation
# Epoch 1, Overall loss = 2.08e+05 and relative error of 0.555
# Training
# Iteration 0: with minibatch training loss = 1.12e+05 and relative error of 0.45
# Iteration 20: with minibatch training loss = 1.14e+05 and relative error of 0.47
# Iteration 40: with minibatch training loss = 8.07e+04 and relative error of 1
# Iteration 60: with minibatch training loss = 4.75e+04 and relative error of 0.9
# Iteration 80: with minibatch training loss = 1.34e+05 and relative error of 0.6
# Iteration 100: with minibatch training loss = 7.52e+04 and relative error of 0.39
# Epoch 15, Overall loss = 1.47e+05 and relative error of 0.592
# Validation
# Epoch 1, Overall loss = 1.77e+05 and relative error of 0.666
# Training
# Iteration 0: with minibatch training loss = 1.76e+05 and relative error of 0.78
# Iteration 20: with minibatch training loss = 1.4e+05 and relative error of 0.75
# Iteration 40: with minibatch training loss = 1.86e+05 and relative error of 0.43
# Iteration 60: with minibatch training loss = 1.52e+05 and relative error of 0.79
# Iteration 80: with minibatch training loss = 9.51e+04 and relative error of 0.4
# Iteration 100: with minibatch training loss = 1.27e+05 and relative error of 0.37
# Epoch 16, Overall loss = 1.34e+05 and relative error of 0.591
# Validation
# Epoch 1, Overall loss = 2.13e+05 and relative error of 0.653
# Training
# Iteration 0: with minibatch training loss = 9.46e+04 and relative error of 0.48
# Iteration 20: with minibatch training loss = 9.17e+04 and relative error of 0.62
# Iteration 40: with minibatch training loss = 1.11e+05 and relative error of 0.52
# Iteration 60: with minibatch training loss = 9.2e+04 and relative error of 0.95
# Iteration 80: with minibatch training loss = 2.81e+05 and relative error of 0.9
# Iteration 100: with minibatch training loss = 1.16e+05 and relative error of 0.64
# Epoch 17, Overall loss = 1.25e+05 and relative error of 0.587
# Validation
# Epoch 1, Overall loss = 1.6e+05 and relative error of 0.713
# Training
# Iteration 0: with minibatch training loss = 4.5e+04 and relative error of 0.38
# Iteration 20: with minibatch training loss = 1.05e+05 and relative error of 0.57
# Iteration 40: with minibatch training loss = 6.84e+04 and relative error of 0.49
# Iteration 60: with minibatch training loss = 8e+04 and relative error of 0.65
# Iteration 80: with minibatch training loss = 7.37e+04 and relative error of 0.55
# Iteration 100: with minibatch training loss = 1.25e+05 and relative error of 0.59
# Epoch 18, Overall loss = 1.08e+05 and relative error of 0.528
# Validation
# Epoch 1, Overall loss = 1.63e+05 and relative error of 0.653
# Training
# Iteration 0: with minibatch training loss = 9.31e+04 and relative error of 0.43
# Iteration 20: with minibatch training loss = 1.55e+05 and relative error of 0.58
# Iteration 40: with minibatch training loss = 1.19e+05 and relative error of 0.35
# Iteration 60: with minibatch training loss = 1.53e+05 and relative error of 0.52
# Iteration 80: with minibatch training loss = 7.9e+04 and relative error of 0.43
# Iteration 100: with minibatch training loss = 7.07e+04 and relative error of 0.39
# Epoch 19, Overall loss = 1.21e+05 and relative error of 0.532
# Validation
# Epoch 1, Overall loss = 1.44e+05 and relative error of 0.562
# Training
# Iteration 0: with minibatch training loss = 5.36e+04 and relative error of 0.49
# Iteration 20: with minibatch training loss = 1.24e+05 and relative error of 0.33
# Iteration 40: with minibatch training loss = 1.93e+05 and relative error of 0.41
# Iteration 60: with minibatch training loss = 9.71e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 5.98e+04 and relative error of 0.3
# Iteration 100: with minibatch training loss = 1.3e+05 and relative error of 0.33
# Epoch 20, Overall loss = 9.88e+04 and relative error of 0.498
# Validation
# Epoch 1, Overall loss = 1.76e+05 and relative error of 0.766
# Training
# Iteration 0: with minibatch training loss = 1.11e+05 and relative error of 0.77
# Iteration 20: with minibatch training loss = 5.65e+04 and relative error of 0.26
# Iteration 40: with minibatch training loss = 4.55e+04 and relative error of 0.55
# Iteration 60: with minibatch training loss = 9.57e+04 and relative error of 0.44
# Iteration 80: with minibatch training loss = 9.89e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 9.71e+04 and relative error of 0.64
# Epoch 21, Overall loss = 9.84e+04 and relative error of 0.494
# Validation
# Epoch 1, Overall loss = 1.65e+05 and relative error of 0.715
# Training
# Iteration 0: with minibatch training loss = 7.88e+04 and relative error of 0.57
# Iteration 20: with minibatch training loss = 1.47e+05 and relative error of 0.34
# Iteration 40: with minibatch training loss = 1.1e+05 and relative error of 0.99
# Iteration 60: with minibatch training loss = 6.2e+04 and relative error of 0.6
# Iteration 80: with minibatch training loss = 1.05e+05 and relative error of 0.41
# Iteration 100: with minibatch training loss = 7.19e+04 and relative error of 0.56
# Epoch 22, Overall loss = 1.03e+05 and relative error of 0.496
# Validation
# Epoch 1, Overall loss = 1.76e+05 and relative error of 0.541
# Training
# Iteration 0: with minibatch training loss = 5.87e+04 and relative error of 0.47
# Iteration 20: with minibatch training loss = 7.69e+04 and relative error of 0.36
# Iteration 40: with minibatch training loss = 4.42e+04 and relative error of 0.42
# Iteration 60: with minibatch training loss = 1.62e+05 and relative error of 0.39
# Iteration 80: with minibatch training loss = 8.74e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 7.02e+04 and relative error of 0.4
# Epoch 23, Overall loss = 9.53e+04 and relative error of 0.456
# Validation
# Epoch 1, Overall loss = 1.57e+05 and relative error of 0.443
# Training
# Iteration 0: with minibatch training loss = 1.07e+05 and relative error of 0.44
# Iteration 20: with minibatch training loss = 6.54e+04 and relative error of 0.4
# Iteration 40: with minibatch training loss = 4.83e+04 and relative error of 0.33
# Iteration 60: with minibatch training loss = 8.6e+04 and relative error of 0.39
# Iteration 80: with minibatch training loss = 1.03e+05 and relative error of 0.37
# Iteration 100: with minibatch training loss = 6.51e+04 and relative error of 0.43
# Epoch 24, Overall loss = 9.21e+04 and relative error of 0.484
# Validation
# Epoch 1, Overall loss = 1.46e+05 and relative error of 0.587
# Training
# Iteration 0: with minibatch training loss = 8.03e+04 and relative error of 0.53
# Iteration 20: with minibatch training loss = 7.69e+04 and relative error of 0.39
# Iteration 40: with minibatch training loss = 1.3e+05 and relative error of 0.24
# Iteration 60: with minibatch training loss = 1.01e+05 and relative error of 0.44
# Iteration 80: with minibatch training loss = 9.46e+04 and relative error of 0.36
# Iteration 100: with minibatch training loss = 5.74e+04 and relative error of 0.59
# Epoch 25, Overall loss = 8.3e+04 and relative error of 0.438
# Validation
# Epoch 1, Overall loss = 1.68e+05 and relative error of 0.496
# Training
# Iteration 0: with minibatch training loss = 9.31e+04 and relative error of 0.37
# Iteration 20: with minibatch training loss = 7.32e+04 and relative error of 0.87
# Iteration 40: with minibatch training loss = 1.15e+05 and relative error of 0.56
# Iteration 60: with minibatch training loss = 8.2e+04 and relative error of 0.44
# Iteration 80: with minibatch training loss = 6.21e+04 and relative error of 0.27
# Iteration 100: with minibatch training loss = 1.47e+05 and relative error of 0.77
# Epoch 26, Overall loss = 1.04e+05 and relative error of 0.502
# Validation
# Epoch 1, Overall loss = 1.9e+05 and relative error of 0.487
# Training
# Iteration 0: with minibatch training loss = 1.93e+05 and relative error of 0.47
# Iteration 20: with minibatch training loss = 4.2e+04 and relative error of 0.31
# Iteration 40: with minibatch training loss = 9.91e+04 and relative error of 0.26
# Iteration 60: with minibatch training loss = 3.91e+04 and relative error of 0.48
# Iteration 80: with minibatch training loss = 5.71e+04 and relative error of 0.43
# Iteration 100: with minibatch training loss = 1.02e+05 and relative error of 0.4
# Epoch 27, Overall loss = 7.31e+04 and relative error of 0.43
# Validation
# Epoch 1, Overall loss = 1.5e+05 and relative error of 0.456
# Training
# Iteration 0: with minibatch training loss = 1.04e+05 and relative error of 0.3
# Iteration 20: with minibatch training loss = 4.68e+04 and relative error of 0.37
# Iteration 40: with minibatch training loss = 4.44e+04 and relative error of 0.66
# Iteration 60: with minibatch training loss = 6.29e+04 and relative error of 0.43
# Iteration 80: with minibatch training loss = 6.88e+04 and relative error of 0.4
# Iteration 100: with minibatch training loss = 4.52e+04 and relative error of 0.28
# Epoch 28, Overall loss = 6.73e+04 and relative error of 0.395
# Validation
# Epoch 1, Overall loss = 1.39e+05 and relative error of 0.545
# Training
# Iteration 0: with minibatch training loss = 8.89e+04 and relative error of 0.32
# Iteration 20: with minibatch training loss = 8.88e+04 and relative error of 0.41
# Iteration 40: with minibatch training loss = 4.5e+04 and relative error of 0.33
# Iteration 60: with minibatch training loss = 6.4e+04 and relative error of 0.39
# Iteration 80: with minibatch training loss = 5.54e+04 and relative error of 0.41
# Iteration 100: with minibatch training loss = 4.18e+04 and relative error of 0.43
# Epoch 29, Overall loss = 7.41e+04 and relative error of 0.419
# Validation
# Epoch 1, Overall loss = 1.43e+05 and relative error of 0.474
# Training
# Iteration 0: with minibatch training loss = 4.07e+04 and relative error of 0.34
# Iteration 20: with minibatch training loss = 6.9e+04 and relative error of 0.37
# Iteration 40: with minibatch training loss = 8.3e+04 and relative error of 0.3
# Iteration 60: with minibatch training loss = 1.09e+05 and relative error of 0.46
# Iteration 80: with minibatch training loss = 7.97e+04 and relative error of 0.36
# Iteration 100: with minibatch training loss = 1.13e+05 and relative error of 0.46
# Epoch 30, Overall loss = 8.05e+04 and relative error of 0.402
# Validation
# Epoch 1, Overall loss = 1.43e+05 and relative error of 0.64
# Training
# Iteration 0: with minibatch training loss = 9.06e+04 and relative error of 0.58
# Iteration 20: with minibatch training loss = 1.15e+05 and relative error of 0.42
# Iteration 40: with minibatch training loss = 9.61e+04 and relative error of 0.63
# Iteration 60: with minibatch training loss = 7.85e+04 and relative error of 0.49
# Iteration 80: with minibatch training loss = 6.98e+04 and relative error of 0.43
# Iteration 100: with minibatch training loss = 4.37e+04 and relative error of 0.44
# Epoch 31, Overall loss = 9.88e+04 and relative error of 0.476
# Validation
# Epoch 1, Overall loss = 1.55e+05 and relative error of 0.52
# Training
# Iteration 0: with minibatch training loss = 4.69e+04 and relative error of 0.42
# Iteration 20: with minibatch training loss = 7.31e+04 and relative error of 0.47
# Iteration 40: with minibatch training loss = 9.8e+04 and relative error of 0.65
# Iteration 60: with minibatch training loss = 9.7e+04 and relative error of 0.45
# Iteration 80: with minibatch training loss = 8.73e+04 and relative error of 0.77
# Iteration 100: with minibatch training loss = 4.01e+04 and relative error of 0.4
# Epoch 32, Overall loss = 8.06e+04 and relative error of 0.442
# Validation
# Epoch 1, Overall loss = 1.41e+05 and relative error of 0.487
# Training
# Iteration 0: with minibatch training loss = 4.3e+04 and relative error of 0.48
# Iteration 20: with minibatch training loss = 5.67e+04 and relative error of 0.42
# Iteration 40: with minibatch training loss = 5.59e+04 and relative error of 0.37
# Iteration 60: with minibatch training loss = 3.42e+04 and relative error of 0.44
# Iteration 80: with minibatch training loss = 3.03e+04 and relative error of 0.35
# Iteration 100: with minibatch training loss = 9.67e+04 and relative error of 0.29
# Epoch 33, Overall loss = 7.88e+04 and relative error of 0.387
# Validation
# Epoch 1, Overall loss = 1.62e+05 and relative error of 0.49
# Training
# Iteration 0: with minibatch training loss = 6.55e+04 and relative error of 0.32
# Iteration 20: with minibatch training loss = 6.43e+04 and relative error of 0.34
# Iteration 40: with minibatch training loss = 4.94e+04 and relative error of 0.3
# Iteration 60: with minibatch training loss = 4.91e+04 and relative error of 0.26
# Iteration 80: with minibatch training loss = 7.01e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 3.65e+04 and relative error of 0.34
# Epoch 34, Overall loss = 6.36e+04 and relative error of 0.388
# Validation
# Epoch 1, Overall loss = 1.37e+05 and relative error of 0.425
# Training
# Iteration 0: with minibatch training loss = 5.18e+04 and relative error of 0.39
# Iteration 20: with minibatch training loss = 8.56e+04 and relative error of 0.37
# Iteration 40: with minibatch training loss = 1.31e+05 and relative error of 0.44
# Iteration 60: with minibatch training loss = 7.12e+04 and relative error of 0.26
# Iteration 80: with minibatch training loss = 2.33e+04 and relative error of 0.26
# Iteration 100: with minibatch training loss = 5.07e+04 and relative error of 0.3
# Epoch 35, Overall loss = 6.5e+04 and relative error of 0.368
# Validation
# Epoch 1, Overall loss = 1.56e+05 and relative error of 0.442
# Training
# Iteration 0: with minibatch training loss = 4.37e+04 and relative error of 0.29
# Iteration 20: with minibatch training loss = 8.11e+04 and relative error of 0.36
# Iteration 40: with minibatch training loss = 8.36e+04 and relative error of 0.19
# Iteration 60: with minibatch training loss = 2.52e+04 and relative error of 0.38
# Iteration 80: with minibatch training loss = 5.85e+04 and relative error of 0.31
# Iteration 100: with minibatch training loss = 7.36e+04 and relative error of 0.24
# Epoch 36, Overall loss = 5.87e+04 and relative error of 0.344
# Validation
# Epoch 1, Overall loss = 1.4e+05 and relative error of 0.402
# Training
# Iteration 0: with minibatch training loss = 4.97e+04 and relative error of 0.25
# Iteration 20: with minibatch training loss = 6.47e+04 and relative error of 0.23
# Iteration 40: with minibatch training loss = 4.51e+04 and relative error of 0.35
# Iteration 60: with minibatch training loss = 5.04e+04 and relative error of 0.51
# Iteration 80: with minibatch training loss = 5.2e+04 and relative error of 0.39
# Iteration 100: with minibatch training loss = 5.73e+04 and relative error of 0.5
# Epoch 37, Overall loss = 6.47e+04 and relative error of 0.362
# Validation
# Epoch 1, Overall loss = 1.51e+05 and relative error of 0.376
# Training
# Iteration 0: with minibatch training loss = 6.33e+04 and relative error of 0.27
# Iteration 20: with minibatch training loss = 5.32e+04 and relative error of 0.27
# Iteration 40: with minibatch training loss = 8.24e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 5.59e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 4.91e+04 and relative error of 0.37
# Iteration 100: with minibatch training loss = 5.94e+04 and relative error of 0.4
# Epoch 38, Overall loss = 6.39e+04 and relative error of 0.353
# Validation
# Epoch 1, Overall loss = 1.44e+05 and relative error of 0.391
# Training
# Iteration 0: with minibatch training loss = 5.37e+04 and relative error of 0.33
# Iteration 20: with minibatch training loss = 6.06e+04 and relative error of 0.5
# Iteration 40: with minibatch training loss = 2.87e+04 and relative error of 0.24
# Iteration 60: with minibatch training loss = 6.03e+04 and relative error of 0.32
# Iteration 80: with minibatch training loss = 4.37e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 4.38e+04 and relative error of 0.33
# Epoch 39, Overall loss = 5.94e+04 and relative error of 0.324
# Validation
# Epoch 1, Overall loss = 1.46e+05 and relative error of 0.361
# Training
# Iteration 0: with minibatch training loss = 5.55e+04 and relative error of 0.29
# Iteration 20: with minibatch training loss = 6.6e+04 and relative error of 0.26
# Iteration 40: with minibatch training loss = 9.99e+04 and relative error of 0.29
# Iteration 60: with minibatch training loss = 5.49e+04 and relative error of 0.36
# Iteration 80: with minibatch training loss = 4.74e+04 and relative error of 0.33
# Iteration 100: with minibatch training loss = 3.88e+04 and relative error of 0.22
# Epoch 40, Overall loss = 5.69e+04 and relative error of 0.331
# Validation
# Epoch 1, Overall loss = 1.86e+05 and relative error of 0.4
# Model saved in file: cnn_depth8_wider.ckpt

# %%
# keep training
num_epochs = 20
for epoch_idx in range(num_epochs):
    print('Training')
    train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                        x_var,y_var,is_training,
                                        X_train, y_train, epoch_idx, 100, 20, train_step,False)
    print('Validation')
    val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                    x_var, y_var, is_training, X_val, y_val)
    
    train_loss_hist.append(train_loss)
    train_error_hist.append(train_error)
    val_loss_hist.append(val_loss)
    val_error_hist.append(val_error)

# Saving the model
model_name = "cnn_depth6_wider"
saver = tf.train.Saver()
save_path = saver.save(sess, model_name + ".ckpt")
print("Model saved in file: %s" % save_path)

# Saving training history
train_loss = np.array(train_loss_hist)
np.save(model_name+"_train_loss", train_loss)
train_error = np.array(train_error_hist)
np.save(model_name+"_train_error", train_error)
val_loss = np.array(val_loss_hist)
np.save(model_name+"_val_loss", val_loss)
val_error = np.array(val_error_hist)
np.save(model_name+"_val_error", val_error)

# %%
# loading the model
saver = tf.train.Saver()
sess = tf.Session()
save_path = "./cnn_depth6_wider.ckpt"
saver.restore(sess, save_path)
print("Model restored.")
# Out:
# Model restored.

# %%
# Plotting final results
# plot training loss history
plt.plot(train_loss_hist,label= 'training loss history')
plt.plot(val_loss_hist,label= 'validation loss history')
plt.yscale('log')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('training loss')
plt.legend()
plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# plot relative error history
plt.plot(train_error_hist[7:], label='training relative error')
plt.plot(val_error_hist[7:], label='validation relative error')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('relative error')
plt.legend()
plt.savefig('relative_error.png', bbox_inches='tight')
plt.show()

# %%
test_out = sess.run(pred_y_var, {x_var: images_test, is_training:False})
plt.plot(test_out)
plt.plot(pv_test)
plt.show()

# %%
idx1 = np.arange(0,491) # a sunny day at 12-20-16
idx2 = np.arange(2730,3145) # a cloudy day at 1-1-17
idx3 = np.arange(5420,5843) # a rainy  day at 1-8-17

idx = np.concatenate((idx1,idx2,idx3))

print(idx.shape)
# Out:
# (1329,)

# %%
idx= idx
feed_dict = {x_var: images[idx],y_var: pv_out[idx],is_training: False}

mse,pred_y_value = sess.run([mean_loss,pred_y_var], feed_dict=feed_dict)

plt.plot(pv_out[idx], label='actual pv output')
plt.plot(pred_y_value, label='predicted pv output')
plt.grid(True)
plt.xlabel('image index')
plt.ylabel('panel output (Btu/hr)')
plt.legend()
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.rc('font',size=15)

plt.savefig('predicted_and_actual_output.png', bbox_inches='tight')
plt.show()

print('RMSE: ', np.sqrt(mse))
# Out:
# RMSE:  277.075
