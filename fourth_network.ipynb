# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# Loading in and dividing data
# reads in data
images = np.load("images.npy")
pv_out = np.load("pv_outputs.npy")

# randomly divides into a training set and a validation set
num_imgs = images.shape[0]
indices = np.arange(num_imgs)
np.random.shuffle(indices)
X_train, X_val = images[indices[:int(0.8 * num_imgs)]], images[indices[int(0.8 * num_imgs):]]
y_train, y_val = pv_out[indices[:int(0.8 * num_imgs)]], pv_out[indices[int(0.8 * num_imgs):]]

# %%
# The model
def cnn_model_depth6(X, y, is_training):
    # CBP sandwich 1
    conv1 = tf.layers.conv2d(
        inputs=X,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn1 = tf.layers.batch_normalization(inputs=conv1, axis=1)
    conv2 = tf.layers.conv2d(
        inputs=bn1,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn2 = tf.layers.batch_normalization(inputs=conv2, axis=1)
    conv3 = tf.layers.conv2d(
        inputs=bn2,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    conv4 = tf.layers.conv2d(
        inputs=bn3,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn4 = tf.layers.batch_normalization(inputs=conv4, axis=1)
    pool1 = tf.layers.max_pooling2d(inputs=bn4, pool_size=[2, 2], strides=2)

    # CBP sandwich 2
    conv5 = tf.layers.conv2d(
        inputs=pool1,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn5 = tf.layers.batch_normalization(inputs=conv5, axis=1)
    conv6 = tf.layers.conv2d(
        inputs=bn5,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn6 = tf.layers.batch_normalization(inputs=conv6, axis=1)

    
    pool2_flat = tf.reshape(bn6, [-1, 30 * 30 * 64])
    
    # Fully connected nets
    dense1 = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    bn_dense1 = tf.layers.batch_normalization(inputs=dense1)
    dropout1 = tf.layers.dropout(
        inputs=bn_dense1, rate=0.4, training=is_training)
    dense2 = tf.layers.dense(inputs=dropout1, units=1024, activation=tf.nn.relu)
    bn_dense2 = tf.layers.batch_normalization(inputs=dense2)
    dropout2 = tf.layers.dropout(
        inputs=bn_dense2, rate=0.4, training=is_training)
    dense3 = tf.layers.dense(inputs=dropout2, units=1024, activation=tf.nn.relu)
    bn_dense3 = tf.layers.batch_normalization(inputs=dense3)
    dropout3 = tf.layers.dropout(
        inputs=bn_dense3, rate=0.4, training=is_training)
    
    regression = tf.layers.dense(inputs=dropout3, units=1)
    regression = tf.reshape(regression, [-1])
    return regression

# %%
# Run model 
def run_model(session, pred_y_var, loss_var,
              x_var,y_var,is_training, Xd, yd,
              epoch_idx=0, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    rel_err_var = tf.divide(tf.abs(tf.subtract(y_var, pred_y_var)), y_var)
    accuracy = tf.reduce_mean(rel_err_var)

    # shuffle indices
    train_indices = np.arange(Xd.shape[0])
    np.random.shuffle(train_indices)
    training_now = training is not None

    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_var, rel_err_var, accuracy]
    if training_now:
        variables[-1] = training

    # counter
    iter_cnt = 0

    # keep track of losses and accuracy
    errors = 0
    losses = []

    # make sure we iterate over the dataset once
    for i in range(int(Xd.shape[0] / batch_size)+1):
        # generate indices for the batch
        start_idx = (i * batch_size) % Xd.shape[0]
        idx = train_indices[start_idx:start_idx + batch_size]

        # create a feed dictionary for this batch
        feed_dict = {x_var: Xd[idx, :],
                     y_var: yd[idx],
                     is_training: training_now}
        # get batch size
        actual_batch_size = yd[i:i + batch_size].shape[0]

        # have tensorflow compute loss and correct predictions
        # and (if given) perform a training step
        loss, rel_err, _ = session.run(variables, feed_dict=feed_dict)

        # aggregate performance stats
        losses.append(loss * actual_batch_size)
        errors += np.sum(rel_err)

        # print every now and then
        if training_now and (iter_cnt % print_every) == 0:
            print("Iteration {0}: with minibatch training loss = {1:.3g} and relative error of {2:.2g}"
                  .format(iter_cnt, loss, np.sum(rel_err) / actual_batch_size))
        iter_cnt += 1
    total_error = errors / Xd.shape[0]
    total_loss = np.sum(losses) / Xd.shape[0]

    print("Epoch {2}, Overall loss = {0:.3g} and relative error of {1:.3g}"
          .format(total_loss, total_error, epoch_idx+1 ))

    if plot_losses:
        plt.plot(losses)
        plt.grid(True)
        plt.title('Epoch {} Loss'.format(epoch_idx + 1))
        plt.xlabel('minibatch number')
        plt.ylabel('minibatch loss')
        plt.show()

    return total_loss, total_error

# %%
# Build computational graph
tf.reset_default_graph()  # Reset computational graph

x_var = tf.placeholder(tf.float32, [None, 60, 60, 3]) # x variable
y_var = tf.placeholder(tf.float32, [None]) # y variable
is_training = tf.placeholder(tf.bool) # flag
pred_y_var = cnn_model_depth6(x_var, y_var, is_training) # model in use
mean_loss = tf.losses.mean_squared_error(y_var, pred_y_var) # loss in use

# Define optimizer and optimize session parameter
# define optimizer
optimizer = tf.train.AdamOptimizer(1e-3)
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)
pass

# %%
# Train the model
# initialize all variable
num_epochs = 20
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# initialize loss and rel_err history list
train_loss_hist = []
train_error_hist = []
val_loss_hist = []
val_error_hist = []

for epoch_idx in range(num_epochs):
    print('Training')
    train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                        x_var,y_var,is_training,
                                        X_train, y_train, epoch_idx, 100, 20, train_step,False)
    print('Validation')
    val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                    x_var, y_var, is_training, X_val, y_val)
    
    train_loss_hist.append(train_loss)
    train_error_hist.append(train_error)
    val_loss_hist.append(val_loss)
    val_error_hist.append(val_error)

# Saving the model
model_name = "cnn_depth6"
saver = tf.train.Saver()
save_path = saver.save(sess, model_name + ".ckpt")
print("Model saved in file: %s" % save_path)

# Saving training history
train_loss = np.array(train_loss_hist)
np.save(model_name+"_train_loss", train_loss)
train_error = np.array(train_error_hist)
np.save(model_name+"_train_error", train_error)
val_loss = np.array(val_loss_hist)
np.save(model_name+"_val_loss", val_loss)
val_error = np.array(val_error_hist)
np.save(model_name+"_val_error", val_error)
# Out:
# Training
# Iteration 0: with minibatch training loss = 5.1e+06 and relative error of 1
# Iteration 20: with minibatch training loss = 3.09e+06 and relative error of 3.3
# Iteration 40: with minibatch training loss = 1.86e+06 and relative error of 9.8
# Iteration 60: with minibatch training loss = 1e+06 and relative error of 1.1
# Iteration 80: with minibatch training loss = 5.4e+05 and relative error of 2.4
# Iteration 100: with minibatch training loss = 4.36e+05 and relative error of 0.85
# Epoch 1, Overall loss = 1.54e+06 and relative error of 4.63
# Validation
# Epoch 1, Overall loss = 3.02e+05 and relative error of 1.5
# Training
# Iteration 0: with minibatch training loss = 2.49e+05 and relative error of 1.5
# Iteration 20: with minibatch training loss = 3.32e+05 and relative error of 1.2
# Iteration 40: with minibatch training loss = 4.85e+05 and relative error of 1.4
# Iteration 60: with minibatch training loss = 3.76e+05 and relative error of 0.88
# Iteration 80: with minibatch training loss = 3.87e+05 and relative error of 2.2
# Iteration 100: with minibatch training loss = 7.37e+05 and relative error of 1.1
# Epoch 2, Overall loss = 4.11e+05 and relative error of 1.45
# Validation
# Epoch 1, Overall loss = 2.56e+05 and relative error of 1.7
# Training
# Iteration 0: with minibatch training loss = 5.46e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 1.57e+05 and relative error of 1.1
# Iteration 40: with minibatch training loss = 2.65e+05 and relative error of 0.77
# Iteration 60: with minibatch training loss = 3.24e+05 and relative error of 0.9
# Iteration 80: with minibatch training loss = 3.21e+05 and relative error of 1.8
# Iteration 100: with minibatch training loss = 2.94e+05 and relative error of 1.1
# Epoch 3, Overall loss = 2.96e+05 and relative error of 1.06
# Validation
# Epoch 1, Overall loss = 1.87e+05 and relative error of 1.51
# Training
# Iteration 0: with minibatch training loss = 2.25e+05 and relative error of 0.66
# Iteration 20: with minibatch training loss = 1.49e+05 and relative error of 0.67
# Iteration 40: with minibatch training loss = 6.17e+05 and relative error of 0.64
# Iteration 60: with minibatch training loss = 3e+05 and relative error of 1.1
# Iteration 80: with minibatch training loss = 2.07e+05 and relative error of 1
# Iteration 100: with minibatch training loss = 4.12e+05 and relative error of 1.4
# Epoch 4, Overall loss = 2.9e+05 and relative error of 1.02
# Validation
# Epoch 1, Overall loss = 1.84e+05 and relative error of 1.26
# Training
# Iteration 0: with minibatch training loss = 2.64e+05 and relative error of 0.68
# Iteration 20: with minibatch training loss = 6.19e+05 and relative error of 1.5
# Iteration 40: with minibatch training loss = 2.32e+05 and relative error of 0.83
# Iteration 60: with minibatch training loss = 1.27e+05 and relative error of 0.56
# Iteration 80: with minibatch training loss = 1.84e+05 and relative error of 1.4
# Iteration 100: with minibatch training loss = 2.96e+05 and relative error of 0.79
# Epoch 5, Overall loss = 2.77e+05 and relative error of 0.852
# Validation
# Epoch 1, Overall loss = 1.8e+05 and relative error of 1.15
# Training
# Iteration 0: with minibatch training loss = 1.11e+05 and relative error of 0.37
# Iteration 20: with minibatch training loss = 1.09e+05 and relative error of 0.75
# Iteration 40: with minibatch training loss = 2.23e+05 and relative error of 0.9
# Iteration 60: with minibatch training loss = 3.01e+05 and relative error of 1
# Iteration 80: with minibatch training loss = 4.24e+05 and relative error of 0.64
# Iteration 100: with minibatch training loss = 1.74e+05 and relative error of 0.61
# Epoch 6, Overall loss = 2.56e+05 and relative error of 0.759
# Validation
# Epoch 1, Overall loss = 1.92e+05 and relative error of 0.702
# Training
# Iteration 0: with minibatch training loss = 1.17e+05 and relative error of 0.58
# Iteration 20: with minibatch training loss = 9.53e+04 and relative error of 0.87
# Iteration 40: with minibatch training loss = 2.43e+05 and relative error of 0.68
# Iteration 60: with minibatch training loss = 6.46e+04 and relative error of 0.95
# Iteration 80: with minibatch training loss = 1.2e+05 and relative error of 0.6
# Iteration 100: with minibatch training loss = 1.26e+05 and relative error of 0.41
# Epoch 7, Overall loss = 1.91e+05 and relative error of 0.662
# Validation
# Epoch 1, Overall loss = 1.39e+05 and relative error of 0.962
# Training
# Iteration 0: with minibatch training loss = 1.39e+05 and relative error of 0.73
# Iteration 20: with minibatch training loss = 2.8e+05 and relative error of 0.41
# Iteration 40: with minibatch training loss = 2.23e+05 and relative error of 0.94
# Iteration 60: with minibatch training loss = 1.32e+05 and relative error of 0.69
# Iteration 80: with minibatch training loss = 1.55e+05 and relative error of 0.89
# Iteration 100: with minibatch training loss = 3.03e+05 and relative error of 0.56
# Epoch 8, Overall loss = 1.82e+05 and relative error of 0.62
# Validation
# Epoch 1, Overall loss = 1.71e+05 and relative error of 0.651
# Training
# Iteration 0: with minibatch training loss = 1.47e+05 and relative error of 0.4
# Iteration 20: with minibatch training loss = 1.48e+05 and relative error of 0.28
# Iteration 40: with minibatch training loss = 1.96e+05 and relative error of 0.69
# Iteration 60: with minibatch training loss = 2.54e+05 and relative error of 0.37
# Iteration 80: with minibatch training loss = 1.69e+05 and relative error of 0.44
# Iteration 100: with minibatch training loss = 9.31e+04 and relative error of 0.81
# Epoch 9, Overall loss = 1.68e+05 and relative error of 0.589
# Validation
# Epoch 1, Overall loss = 1.26e+05 and relative error of 0.643
# Training
# Iteration 0: with minibatch training loss = 1.1e+05 and relative error of 0.54
# Iteration 20: with minibatch training loss = 2.8e+05 and relative error of 0.29
# Iteration 40: with minibatch training loss = 1.26e+05 and relative error of 0.43
# Iteration 60: with minibatch training loss = 2.54e+05 and relative error of 0.39
# Iteration 80: with minibatch training loss = 6.06e+04 and relative error of 0.26
# Iteration 100: with minibatch training loss = 3.38e+05 and relative error of 0.38
# Epoch 10, Overall loss = 1.74e+05 and relative error of 0.53
# Validation
# Epoch 1, Overall loss = 1.1e+05 and relative error of 0.613
# Training
# Iteration 0: with minibatch training loss = 8.1e+04 and relative error of 0.42
# Iteration 20: with minibatch training loss = 6.01e+04 and relative error of 0.45
# Iteration 40: with minibatch training loss = 1.44e+05 and relative error of 0.31
# Iteration 60: with minibatch training loss = 1.09e+05 and relative error of 0.38
# Iteration 80: with minibatch training loss = 1.47e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 9.73e+04 and relative error of 0.46
# Epoch 11, Overall loss = 1.57e+05 and relative error of 0.514
# Validation
# Epoch 1, Overall loss = 1.51e+05 and relative error of 0.546
# Training
# Iteration 0: with minibatch training loss = 1.88e+05 and relative error of 0.62
# Iteration 20: with minibatch training loss = 1.03e+05 and relative error of 0.88
# Iteration 40: with minibatch training loss = 1.02e+05 and relative error of 0.45
# Iteration 60: with minibatch training loss = 9.28e+04 and relative error of 0.5
# Iteration 80: with minibatch training loss = 1.32e+05 and relative error of 0.53
# Iteration 100: with minibatch training loss = 2.04e+05 and relative error of 0.63
# Epoch 12, Overall loss = 1.72e+05 and relative error of 0.58
# Validation
# Epoch 1, Overall loss = 1.48e+05 and relative error of 0.561
# Training
# Iteration 0: with minibatch training loss = 1.54e+05 and relative error of 0.68
# Iteration 20: with minibatch training loss = 2.05e+05 and relative error of 0.6
# Iteration 40: with minibatch training loss = 8.53e+04 and relative error of 0.51
# Iteration 60: with minibatch training loss = 8.49e+04 and relative error of 0.34
# Iteration 80: with minibatch training loss = 1.22e+05 and relative error of 0.47
# Iteration 100: with minibatch training loss = 4.91e+04 and relative error of 0.51
# Epoch 13, Overall loss = 1.24e+05 and relative error of 0.446
# Validation
# Epoch 1, Overall loss = 1.55e+05 and relative error of 0.6
# Training
# Iteration 0: with minibatch training loss = 1.5e+05 and relative error of 0.39
# Iteration 20: with minibatch training loss = 5.29e+04 and relative error of 0.49
# Iteration 40: with minibatch training loss = 9.55e+04 and relative error of 0.34
# Iteration 60: with minibatch training loss = 5.93e+04 and relative error of 0.44
# Iteration 80: with minibatch training loss = 1.21e+05 and relative error of 0.2
# Iteration 100: with minibatch training loss = 7.62e+04 and relative error of 0.41
# Epoch 14, Overall loss = 1.24e+05 and relative error of 0.434
# Validation
# Epoch 1, Overall loss = 1.34e+05 and relative error of 0.413
# Training
# Iteration 0: with minibatch training loss = 2.95e+05 and relative error of 0.68
# Iteration 20: with minibatch training loss = 1.27e+05 and relative error of 0.67
# Iteration 40: with minibatch training loss = 7.53e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 7.76e+04 and relative error of 0.35
# Iteration 80: with minibatch training loss = 1.14e+05 and relative error of 0.32
# Iteration 100: with minibatch training loss = 9.1e+04 and relative error of 0.66
# Epoch 15, Overall loss = 1.22e+05 and relative error of 0.439
# Validation
# Epoch 1, Overall loss = 1.14e+05 and relative error of 0.457
# Training
# Iteration 0: with minibatch training loss = 9.17e+04 and relative error of 0.41
# Iteration 20: with minibatch training loss = 1.8e+05 and relative error of 0.68
# Iteration 40: with minibatch training loss = 6.97e+04 and relative error of 0.32
# Iteration 60: with minibatch training loss = 1.77e+05 and relative error of 0.41
# Iteration 80: with minibatch training loss = 6.35e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 2.6e+05 and relative error of 0.36
# Epoch 16, Overall loss = 1.17e+05 and relative error of 0.416
# Validation
# Epoch 1, Overall loss = 2.08e+05 and relative error of 0.384
# Training
# Iteration 0: with minibatch training loss = 2.7e+05 and relative error of 0.21
# Iteration 20: with minibatch training loss = 1.3e+05 and relative error of 0.31
# Iteration 40: with minibatch training loss = 8.53e+04 and relative error of 0.26
# Iteration 60: with minibatch training loss = 1.56e+05 and relative error of 0.38
# Iteration 80: with minibatch training loss = 1.66e+05 and relative error of 0.25
# Iteration 100: with minibatch training loss = 1.16e+05 and relative error of 0.49
# Epoch 17, Overall loss = 9.59e+04 and relative error of 0.364
# Validation
# Epoch 1, Overall loss = 1.05e+05 and relative error of 0.508
# Training
# Iteration 0: with minibatch training loss = 8.31e+04 and relative error of 0.43
# Iteration 20: with minibatch training loss = 7.86e+04 and relative error of 0.26
# Iteration 40: with minibatch training loss = 8.87e+04 and relative error of 0.27
# Iteration 60: with minibatch training loss = 6.84e+04 and relative error of 0.28
# Iteration 80: with minibatch training loss = 8.24e+04 and relative error of 0.39
# Iteration 100: with minibatch training loss = 1.41e+05 and relative error of 0.4
# Epoch 18, Overall loss = 9.6e+04 and relative error of 0.38
# Validation
# Epoch 1, Overall loss = 1.08e+05 and relative error of 0.524
# Training
# Iteration 0: with minibatch training loss = 1.05e+05 and relative error of 0.45
# Iteration 20: with minibatch training loss = 1.12e+05 and relative error of 0.31
# Iteration 40: with minibatch training loss = 1.76e+05 and relative error of 0.46
# Iteration 60: with minibatch training loss = 7.93e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 7.23e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 7.7e+04 and relative error of 0.23
# Epoch 19, Overall loss = 9.71e+04 and relative error of 0.386
# Validation
# Epoch 1, Overall loss = 9.96e+04 and relative error of 0.417
# Training
# Iteration 0: with minibatch training loss = 4.84e+04 and relative error of 0.39
# Iteration 20: with minibatch training loss = 1.06e+05 and relative error of 0.35
# Iteration 40: with minibatch training loss = 4.48e+04 and relative error of 0.4
# Iteration 60: with minibatch training loss = 6.95e+04 and relative error of 0.38
# Iteration 80: with minibatch training loss = 1.07e+05 and relative error of 0.31
# Iteration 100: with minibatch training loss = 3.32e+04 and relative error of 0.34
# Epoch 20, Overall loss = 9.12e+04 and relative error of 0.341
# Validation
# Epoch 1, Overall loss = 1.07e+05 and relative error of 0.327
# Model saved in file: cnn_depth6.ckpt

# %%
# loading the model
saver = tf.train.Saver()
sess = tf.Session()
save_path = "./cnn_depth6.ckpt"
saver.restore(sess, save_path)
print("Model restored.")
# Out:
# Model restored.

# %%
# Plotting final results
# plot training loss history
plt.plot(train_loss_hist,label= 'training loss history')
plt.plot(val_loss_hist,label= 'validation loss history')
plt.yscale('log')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('training loss')
plt.legend()
plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# plot relative error history
plt.plot(train_error_hist[7:], label='training relative error')
plt.plot(val_error_hist[7:], label='validation relative error')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('relative error')
plt.legend()
plt.savefig('relative_error.png', bbox_inches='tight')
plt.show()

# %%
idx1 = np.arange(0,491) # a sunny day at 12-20-16
idx2 = np.arange(2730,3145) # a cloudy day at 1-1-17
idx3 = np.arange(5420,5843) # a rainy  day at 1-8-17

idx = np.concatenate((idx1,idx2,idx3))

print(idx.shape)
# Out:
# (1329,)

# %%
idx= idx
feed_dict = {x_var: images[idx],y_var: pv_out[idx],is_training: False}

mse,pred_y_value = sess.run([mean_loss,pred_y_var], feed_dict=feed_dict)

plt.plot(pv_out[idx], label='actual pv output')
plt.plot(pred_y_value, label='predicted pv output')
plt.grid(True)
plt.xlabel('image index')
plt.ylabel('panel output (Btu/hr)')
plt.legend()
plt.savefig('predicted_and_actual_output.png', bbox_inches='tight')
plt.show()

print('RMSE: ', np.sqrt(mse))
# Out:
# RMSE:  315.32
