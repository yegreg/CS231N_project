# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# Loading in and dividing data
# reads in data
images = np.load("images.npy")
pv_out = np.load("pv_outputs.npy")


images_test = images[:1400]
pv_test = pv_out[:1400]
images = images[1400:]
pv_out = pv_out[1400:]

# randomly divides into a training set and a validation set
num_imgs = images.shape[0]
indices = np.arange(num_imgs)
np.random.shuffle(indices)
X_train, X_val = images[indices[:int(0.8 * num_imgs)]], images[indices[int(0.8 * num_imgs):]]
y_train, y_val = pv_out[indices[:int(0.8 * num_imgs)]], pv_out[indices[int(0.8 * num_imgs):]]

# %%
# The model
def cnn_model_depth6_wider(X, y, is_training):
    # CBP sandwich 1
    conv1 = tf.layers.conv2d(
        inputs=X,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn1 = tf.layers.batch_normalization(inputs=conv1, axis=1)
    conv2 = tf.layers.conv2d(
        inputs=bn1,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn2 = tf.layers.batch_normalization(inputs=conv2, axis=1)
    conv3 = tf.layers.conv2d(
        inputs=bn2,
        filters=32,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn3 = tf.layers.batch_normalization(inputs=conv3, axis=1)
    conv4 = tf.layers.conv2d(
        inputs=bn3,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn4 = tf.layers.batch_normalization(inputs=conv4, axis=1)
    pool1 = tf.layers.max_pooling2d(inputs=bn4, pool_size=[2, 2], strides=2)

    # CBP sandwich 2
    conv5 = tf.layers.conv2d(
        inputs=pool1,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn5 = tf.layers.batch_normalization(inputs=conv5, axis=1)
    conv6 = tf.layers.conv2d(
        inputs=bn5,
        filters=64,
        kernel_size=[3, 3],
        padding="same",
        activation=tf.nn.relu)
    bn6 = tf.layers.batch_normalization(inputs=conv6, axis=1)

    
    pool2_flat = tf.reshape(bn6, [-1, 30 * 30 * 64])
    
    # Fully connected nets
    dense1 = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    bn_dense1 = tf.layers.batch_normalization(inputs=dense1)
    dropout1 = tf.layers.dropout(
        inputs=bn_dense1, rate=0.4, training=is_training)
    dense2 = tf.layers.dense(inputs=dropout1, units=1024, activation=tf.nn.relu)
    bn_dense2 = tf.layers.batch_normalization(inputs=dense2)
    dropout2 = tf.layers.dropout(
        inputs=bn_dense2, rate=0.4, training=is_training)
    dense3 = tf.layers.dense(inputs=dropout2, units=1024, activation=tf.nn.relu)
    bn_dense3 = tf.layers.batch_normalization(inputs=dense3)
    dropout3 = tf.layers.dropout(
        inputs=bn_dense3, rate=0.4, training=is_training)
    
    regression = tf.layers.dense(inputs=dropout3, units=1)
    regression = tf.reshape(regression, [-1])
    return regression

# %%
# Run model 
def run_model(session, pred_y_var, loss_var,
              x_var,y_var,is_training, Xd, yd,
              epoch_idx=0, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    rel_err_var = tf.divide(tf.abs(tf.subtract(y_var, pred_y_var)), y_var)
    accuracy = tf.reduce_mean(rel_err_var)

    # shuffle indices
    train_indices = np.arange(Xd.shape[0])
    np.random.shuffle(train_indices)
    training_now = training is not None

    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_var, rel_err_var, accuracy]
    if training_now:
        variables[-1] = training

    # counter
    iter_cnt = 0

    # keep track of losses and accuracy
    errors = 0
    losses = []

    # make sure we iterate over the dataset once
    for i in range(int(Xd.shape[0] / batch_size)+1):
        # generate indices for the batch
        start_idx = (i * batch_size) % Xd.shape[0]
        idx = train_indices[start_idx:start_idx + batch_size]

        # create a feed dictionary for this batch
        feed_dict = {x_var: Xd[idx, :],
                     y_var: yd[idx],
                     is_training: training_now}
        # get batch size
        actual_batch_size = yd[i:i + batch_size].shape[0]

        # have tensorflow compute loss and correct predictions
        # and (if given) perform a training step
        loss, rel_err, _ = session.run(variables, feed_dict=feed_dict)

        # aggregate performance stats
        losses.append(loss * actual_batch_size)
        errors += np.sum(rel_err)

        # print every now and then
        if training_now and (iter_cnt % print_every) == 0:
            print("Iteration {0}: with minibatch training loss = {1:.3g} and relative error of {2:.2g}"
                  .format(iter_cnt, loss, np.sum(rel_err) / actual_batch_size))
        iter_cnt += 1
    total_error = errors / Xd.shape[0]
    total_loss = np.sum(losses) / Xd.shape[0]

    print("Epoch {2}, Overall loss = {0:.3g} and relative error of {1:.3g}"
          .format(total_loss, total_error, epoch_idx+1 ))

    if plot_losses:
        plt.plot(losses)
        plt.grid(True)
        plt.title('Epoch {} Loss'.format(epoch_idx + 1))
        plt.xlabel('minibatch number')
        plt.ylabel('minibatch loss')
        plt.show()

    return total_loss, total_error

# %%
# Build computational graph
tf.reset_default_graph()  # Reset computational graph

x_var = tf.placeholder(tf.float32, [None, 60, 60, 3]) # x variable
y_var = tf.placeholder(tf.float32, [None]) # y variable
is_training = tf.placeholder(tf.bool) # flag
pred_y_var = cnn_model_depth6_wider(x_var, y_var, is_training) # model in use
mean_loss = tf.losses.mean_squared_error(y_var, pred_y_var) # loss in use

# Define optimizer and optimize session parameter
# define optimizer
optimizer = tf.train.AdamOptimizer(1e-3)
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)
pass

# %%
# Train the model
# initialize all variable
num_epochs = 40
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# initialize loss and rel_err history list
train_loss_hist = []
train_error_hist = []
val_loss_hist = []
val_error_hist = []

for epoch_idx in range(num_epochs):
    print('Training')
    train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                        x_var,y_var,is_training,
                                        X_train, y_train, epoch_idx, 100, 20, train_step,False)
    print('Validation')
    val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                    x_var, y_var, is_training, X_val, y_val)
    
    train_loss_hist.append(train_loss)
    train_error_hist.append(train_error)
    val_loss_hist.append(val_loss)
    val_error_hist.append(val_error)

# Saving the model
model_name = "cnn_depth6_wider"
saver = tf.train.Saver()
save_path = saver.save(sess, model_name + ".ckpt")
print("Model saved in file: %s" % save_path)

# Saving training history
train_loss = np.array(train_loss_hist)
np.save(model_name+"_train_loss", train_loss)
train_error = np.array(train_error_hist)
np.save(model_name+"_train_error", train_error)
val_loss = np.array(val_loss_hist)
np.save(model_name+"_val_loss", val_loss)
val_error = np.array(val_error_hist)
np.save(model_name+"_val_error", val_error)
# Out:
# Training
# Iteration 0: with minibatch training loss = 4.23e+06 and relative error of 0.99
# Iteration 20: with minibatch training loss = 1.91e+06 and relative error of 10
# Iteration 40: with minibatch training loss = 1.09e+06 and relative error of 2.3
# Iteration 60: with minibatch training loss = 8e+05 and relative error of 3.1
# Iteration 80: with minibatch training loss = 5.54e+05 and relative error of 1.5
# Iteration 100: with minibatch training loss = 4.27e+05 and relative error of 1.1
# Epoch 1, Overall loss = 1.09e+06 and relative error of 4.09
# Validation
# Epoch 1, Overall loss = 2.55e+05 and relative error of 1.5
# Training
# Iteration 0: with minibatch training loss = 5.08e+05 and relative error of 1.4
# Iteration 20: with minibatch training loss = 2.21e+05 and relative error of 2.1
# Iteration 40: with minibatch training loss = 2.65e+05 and relative error of 1.8
# Iteration 60: with minibatch training loss = 2.73e+05 and relative error of 1
# Iteration 80: with minibatch training loss = 3.49e+05 and relative error of 0.72
# Iteration 100: with minibatch training loss = 2.13e+05 and relative error of 0.89
# Epoch 2, Overall loss = 3.21e+05 and relative error of 1.39
# Validation
# Epoch 1, Overall loss = 3.09e+05 and relative error of 0.905
# Training
# Iteration 0: with minibatch training loss = 3.11e+05 and relative error of 1.3
# Iteration 20: with minibatch training loss = 3.41e+05 and relative error of 0.81
# Iteration 40: with minibatch training loss = 1.53e+05 and relative error of 2
# Iteration 60: with minibatch training loss = 3.12e+05 and relative error of 1.5
# Iteration 80: with minibatch training loss = 2.06e+05 and relative error of 1.1
# Iteration 100: with minibatch training loss = 2.18e+05 and relative error of 0.61
# Epoch 3, Overall loss = 2.82e+05 and relative error of 1.16
# Validation
# Epoch 1, Overall loss = 1.91e+05 and relative error of 1.11
# Training
# Iteration 0: with minibatch training loss = 3.29e+05 and relative error of 0.94
# Iteration 20: with minibatch training loss = 1.18e+05 and relative error of 0.95
# Iteration 40: with minibatch training loss = 2.93e+05 and relative error of 1.1
# Iteration 60: with minibatch training loss = 2.47e+05 and relative error of 1.2
# Iteration 80: with minibatch training loss = 2.18e+05 and relative error of 0.47
# Iteration 100: with minibatch training loss = 1.25e+05 and relative error of 0.83
# Epoch 4, Overall loss = 3.06e+05 and relative error of 1.06
# Validation
# Epoch 1, Overall loss = 1.76e+05 and relative error of 0.82
# Training
# Iteration 0: with minibatch training loss = 2.57e+05 and relative error of 0.78
# Iteration 20: with minibatch training loss = 3.29e+05 and relative error of 0.75
# Iteration 40: with minibatch training loss = 1.25e+05 and relative error of 0.64
# Iteration 60: with minibatch training loss = 6.61e+05 and relative error of 1.7
# Iteration 80: with minibatch training loss = 2.15e+05 and relative error of 1.5
# Iteration 100: with minibatch training loss = 1.54e+05 and relative error of 0.57
# Epoch 5, Overall loss = 2.27e+05 and relative error of 0.864
# Validation
# Epoch 1, Overall loss = 2.64e+05 and relative error of 1.12
# Training
# Iteration 0: with minibatch training loss = 2.93e+05 and relative error of 0.67
# Iteration 20: with minibatch training loss = 2.29e+05 and relative error of 1.4
# Iteration 40: with minibatch training loss = 1.13e+05 and relative error of 0.67
# Iteration 60: with minibatch training loss = 1.51e+05 and relative error of 1.4
# Iteration 80: with minibatch training loss = 2.25e+05 and relative error of 0.38
# Iteration 100: with minibatch training loss = 8.51e+04 and relative error of 0.67
# Epoch 6, Overall loss = 2.19e+05 and relative error of 0.794
# Validation
# Epoch 1, Overall loss = 1.19e+05 and relative error of 0.608
# Training
# Iteration 0: with minibatch training loss = 3.03e+05 and relative error of 0.56
# Iteration 20: with minibatch training loss = 1.07e+05 and relative error of 0.94
# Iteration 40: with minibatch training loss = 2.11e+05 and relative error of 0.99
# Iteration 60: with minibatch training loss = 9.59e+04 and relative error of 0.67
# Iteration 80: with minibatch training loss = 1.17e+05 and relative error of 0.77
# Iteration 100: with minibatch training loss = 7.47e+04 and relative error of 0.57
# Epoch 7, Overall loss = 1.81e+05 and relative error of 0.656
# Validation
# Epoch 1, Overall loss = 1.4e+05 and relative error of 0.574
# Training
# Iteration 0: with minibatch training loss = 1.29e+05 and relative error of 0.76
# Iteration 20: with minibatch training loss = 9.95e+04 and relative error of 0.69
# Iteration 40: with minibatch training loss = 2.98e+05 and relative error of 0.39
# Iteration 60: with minibatch training loss = 1.36e+05 and relative error of 0.34
# Iteration 80: with minibatch training loss = 8.8e+04 and relative error of 0.71
# Iteration 100: with minibatch training loss = 6.28e+04 and relative error of 1
# Epoch 8, Overall loss = 1.73e+05 and relative error of 0.65
# Validation
# Epoch 1, Overall loss = 1.18e+05 and relative error of 0.627
# Training
# Iteration 0: with minibatch training loss = 1.89e+05 and relative error of 0.65
# Iteration 20: with minibatch training loss = 1.41e+05 and relative error of 0.34
# Iteration 40: with minibatch training loss = 1.16e+05 and relative error of 0.59
# Iteration 60: with minibatch training loss = 8.71e+04 and relative error of 0.5
# Iteration 80: with minibatch training loss = 2.18e+05 and relative error of 0.73
# Iteration 100: with minibatch training loss = 3.16e+05 and relative error of 0.68
# Epoch 9, Overall loss = 1.87e+05 and relative error of 0.635
# Validation
# Epoch 1, Overall loss = 2.01e+05 and relative error of 0.653
# Training
# Iteration 0: with minibatch training loss = 1.65e+05 and relative error of 0.71
# Iteration 20: with minibatch training loss = 1.71e+05 and relative error of 0.64
# Iteration 40: with minibatch training loss = 1.68e+05 and relative error of 0.58
# Iteration 60: with minibatch training loss = 1.31e+05 and relative error of 0.59
# Iteration 80: with minibatch training loss = 2.1e+05 and relative error of 1.3
# Iteration 100: with minibatch training loss = 2.14e+05 and relative error of 0.82
# Epoch 10, Overall loss = 1.57e+05 and relative error of 0.613
# Validation
# Epoch 1, Overall loss = 2.85e+05 and relative error of 0.679
# Training
# Iteration 0: with minibatch training loss = 1.32e+05 and relative error of 0.79
# Iteration 20: with minibatch training loss = 1.21e+05 and relative error of 0.74
# Iteration 40: with minibatch training loss = 6.71e+04 and relative error of 0.82
# Iteration 60: with minibatch training loss = 1.28e+05 and relative error of 0.48
# Iteration 80: with minibatch training loss = 1.3e+05 and relative error of 0.55
# Iteration 100: with minibatch training loss = 6.23e+04 and relative error of 0.63
# Epoch 11, Overall loss = 1.51e+05 and relative error of 0.565
# Validation
# Epoch 1, Overall loss = 1.58e+05 and relative error of 0.584
# Training
# Iteration 0: with minibatch training loss = 3.17e+05 and relative error of 0.55
# Iteration 20: with minibatch training loss = 1.27e+05 and relative error of 0.55
# Iteration 40: with minibatch training loss = 1.06e+05 and relative error of 0.47
# Iteration 60: with minibatch training loss = 1.43e+05 and relative error of 0.94
# Iteration 80: with minibatch training loss = 1.34e+05 and relative error of 0.45
# Iteration 100: with minibatch training loss = 6.14e+04 and relative error of 0.53
# Epoch 12, Overall loss = 1.3e+05 and relative error of 0.553
# Validation
# Epoch 1, Overall loss = 1.1e+05 and relative error of 0.542
# Training
# Iteration 0: with minibatch training loss = 3.34e+04 and relative error of 0.56
# Iteration 20: with minibatch training loss = 6.83e+04 and relative error of 0.46
# Iteration 40: with minibatch training loss = 1.1e+05 and relative error of 0.35
# Iteration 60: with minibatch training loss = 1.76e+05 and relative error of 0.45
# Iteration 80: with minibatch training loss = 5.63e+04 and relative error of 0.46
# Iteration 100: with minibatch training loss = 1.14e+05 and relative error of 0.48
# Epoch 13, Overall loss = 1.1e+05 and relative error of 0.483
# Validation
# Epoch 1, Overall loss = 1.02e+05 and relative error of 0.508
# Training
# Iteration 0: with minibatch training loss = 7.42e+04 and relative error of 0.48
# Iteration 20: with minibatch training loss = 1.87e+05 and relative error of 0.49
# Iteration 40: with minibatch training loss = 7.04e+04 and relative error of 0.4
# Iteration 60: with minibatch training loss = 8.9e+04 and relative error of 0.46
# Iteration 80: with minibatch training loss = 1.02e+05 and relative error of 0.57
# Iteration 100: with minibatch training loss = 8.49e+04 and relative error of 0.46
# Epoch 14, Overall loss = 1.03e+05 and relative error of 0.471
# Validation
# Epoch 1, Overall loss = 1.13e+05 and relative error of 0.368
# Training
# Iteration 0: with minibatch training loss = 6.79e+04 and relative error of 0.43
# Iteration 20: with minibatch training loss = 7.53e+04 and relative error of 0.51
# Iteration 40: with minibatch training loss = 9.37e+04 and relative error of 0.36
# Iteration 60: with minibatch training loss = 7.9e+04 and relative error of 0.39
# Iteration 80: with minibatch training loss = 9.92e+04 and relative error of 0.88
# Iteration 100: with minibatch training loss = 1.3e+05 and relative error of 0.46
# Epoch 15, Overall loss = 9.43e+04 and relative error of 0.476
# Validation
# Epoch 1, Overall loss = 1.16e+05 and relative error of 0.573
# Training
# Iteration 0: with minibatch training loss = 1.2e+05 and relative error of 0.35
# Iteration 20: with minibatch training loss = 8.35e+04 and relative error of 0.36
# Iteration 40: with minibatch training loss = 1.25e+05 and relative error of 0.38
# Iteration 60: with minibatch training loss = 2.25e+05 and relative error of 0.55
# Iteration 80: with minibatch training loss = 1.22e+05 and relative error of 0.43
# Iteration 100: with minibatch training loss = 7.79e+04 and relative error of 0.53
# Epoch 16, Overall loss = 9.22e+04 and relative error of 0.437
# Validation
# Epoch 1, Overall loss = 9.45e+04 and relative error of 0.469
# Training
# Iteration 0: with minibatch training loss = 1.53e+05 and relative error of 0.35
# Iteration 20: with minibatch training loss = 1.12e+05 and relative error of 0.47
# Iteration 40: with minibatch training loss = 7.63e+04 and relative error of 0.53
# Iteration 60: with minibatch training loss = 1.5e+05 and relative error of 0.43
# Iteration 80: with minibatch training loss = 8.03e+04 and relative error of 0.44
# Iteration 100: with minibatch training loss = 5.02e+04 and relative error of 0.47
# Epoch 17, Overall loss = 8.53e+04 and relative error of 0.414
# Validation
# Epoch 1, Overall loss = 9.75e+04 and relative error of 0.609
# Training
# Iteration 0: with minibatch training loss = 1.86e+05 and relative error of 0.57
# Iteration 20: with minibatch training loss = 1.03e+05 and relative error of 0.39
# Iteration 40: with minibatch training loss = 6.3e+04 and relative error of 0.62
# Iteration 60: with minibatch training loss = 4.83e+04 and relative error of 0.77
# Iteration 80: with minibatch training loss = 1.08e+05 and relative error of 0.32
# Iteration 100: with minibatch training loss = 6.58e+04 and relative error of 0.24
# Epoch 18, Overall loss = 8.2e+04 and relative error of 0.405
# Validation
# Epoch 1, Overall loss = 1.57e+05 and relative error of 0.382
# Training
# Iteration 0: with minibatch training loss = 1.9e+05 and relative error of 0.41
# Iteration 20: with minibatch training loss = 1.13e+05 and relative error of 0.44
# Iteration 40: with minibatch training loss = 1.16e+05 and relative error of 0.55
# Iteration 60: with minibatch training loss = 1.04e+05 and relative error of 0.35
# Iteration 80: with minibatch training loss = 9.51e+04 and relative error of 0.83
# Iteration 100: with minibatch training loss = 1.85e+05 and relative error of 0.54
# Epoch 19, Overall loss = 1.28e+05 and relative error of 0.505
# Validation
# Epoch 1, Overall loss = 1.26e+05 and relative error of 0.392
# Training
# Iteration 0: with minibatch training loss = 1.17e+05 and relative error of 0.27
# Iteration 20: with minibatch training loss = 6.54e+04 and relative error of 0.42
# Iteration 40: with minibatch training loss = 1.6e+05 and relative error of 0.35
# Iteration 60: with minibatch training loss = 6.14e+04 and relative error of 0.43
# Iteration 80: with minibatch training loss = 7.33e+04 and relative error of 0.39
# Iteration 100: with minibatch training loss = 6.82e+04 and relative error of 0.31
# Epoch 20, Overall loss = 8.37e+04 and relative error of 0.438
# Validation
# Epoch 1, Overall loss = 1.05e+05 and relative error of 0.356
# Training
# Iteration 0: with minibatch training loss = 6.51e+04 and relative error of 0.38
# Iteration 20: with minibatch training loss = 4.81e+04 and relative error of 1
# Iteration 40: with minibatch training loss = 4.98e+04 and relative error of 0.31
# Iteration 60: with minibatch training loss = 6.2e+04 and relative error of 0.61
# Iteration 80: with minibatch training loss = 1.16e+05 and relative error of 0.46
# Iteration 100: with minibatch training loss = 5.78e+04 and relative error of 0.57
# Epoch 21, Overall loss = 8.06e+04 and relative error of 0.389
# Validation
# Epoch 1, Overall loss = 1.11e+05 and relative error of 0.463
# Training
# Iteration 0: with minibatch training loss = 8.28e+04 and relative error of 0.28
# Iteration 20: with minibatch training loss = 1.03e+05 and relative error of 0.37
# Iteration 40: with minibatch training loss = 4.25e+04 and relative error of 0.36
# Iteration 60: with minibatch training loss = 5.62e+04 and relative error of 0.32
# Iteration 80: with minibatch training loss = 5.98e+04 and relative error of 0.28
# Iteration 100: with minibatch training loss = 4.49e+04 and relative error of 0.37
# Epoch 22, Overall loss = 7.79e+04 and relative error of 0.387
# Validation
# Epoch 1, Overall loss = 1.04e+05 and relative error of 0.416
# Training
# Iteration 0: with minibatch training loss = 4.47e+04 and relative error of 0.51
# Iteration 20: with minibatch training loss = 4.83e+04 and relative error of 0.34
# Iteration 40: with minibatch training loss = 3.35e+04 and relative error of 0.45
# Iteration 60: with minibatch training loss = 8.59e+04 and relative error of 0.34
# Iteration 80: with minibatch training loss = 5.53e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 6.56e+04 and relative error of 0.15
# Epoch 23, Overall loss = 6.27e+04 and relative error of 0.365
# Validation
# Epoch 1, Overall loss = 1.09e+05 and relative error of 0.375
# Training
# Iteration 0: with minibatch training loss = 3.43e+04 and relative error of 0.29
# Iteration 20: with minibatch training loss = 4.94e+04 and relative error of 0.42
# Iteration 40: with minibatch training loss = 6.64e+04 and relative error of 0.28
# Iteration 60: with minibatch training loss = 2.36e+04 and relative error of 0.36
# Iteration 80: with minibatch training loss = 6.41e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 2.84e+04 and relative error of 0.3
# Epoch 24, Overall loss = 6.21e+04 and relative error of 0.34
# Validation
# Epoch 1, Overall loss = 1.04e+05 and relative error of 0.368
# Training
# Iteration 0: with minibatch training loss = 9.25e+04 and relative error of 0.32
# Iteration 20: with minibatch training loss = 5.2e+04 and relative error of 0.33
# Iteration 40: with minibatch training loss = 7.97e+04 and relative error of 0.32
# Iteration 60: with minibatch training loss = 8.16e+04 and relative error of 0.37
# Iteration 80: with minibatch training loss = 4.08e+04 and relative error of 0.31
# Iteration 100: with minibatch training loss = 7e+04 and relative error of 0.21
# Epoch 25, Overall loss = 6.27e+04 and relative error of 0.347
# Validation
# Epoch 1, Overall loss = 1.09e+05 and relative error of 0.363
# Training
# Iteration 0: with minibatch training loss = 3.53e+04 and relative error of 0.38
# Iteration 20: with minibatch training loss = 9.44e+04 and relative error of 0.38
# Iteration 40: with minibatch training loss = 8.87e+04 and relative error of 0.38
# Iteration 60: with minibatch training loss = 7.16e+04 and relative error of 0.39
# Iteration 80: with minibatch training loss = 5.43e+04 and relative error of 0.38
# Iteration 100: with minibatch training loss = 4.77e+04 and relative error of 0.22
# Epoch 26, Overall loss = 6.13e+04 and relative error of 0.353
# Validation
# Epoch 1, Overall loss = 9.27e+04 and relative error of 0.37
# Training
# Iteration 0: with minibatch training loss = 5.77e+04 and relative error of 0.31
# Iteration 20: with minibatch training loss = 3.43e+04 and relative error of 0.29
# Iteration 40: with minibatch training loss = 4.52e+04 and relative error of 0.45
# Iteration 60: with minibatch training loss = 4.78e+04 and relative error of 0.2
# Iteration 80: with minibatch training loss = 7.11e+04 and relative error of 0.25
# Iteration 100: with minibatch training loss = 2.93e+04 and relative error of 0.48
# Epoch 27, Overall loss = 6.15e+04 and relative error of 0.345
# Validation
# Epoch 1, Overall loss = 1.1e+05 and relative error of 0.407
# Training
# Iteration 0: with minibatch training loss = 3.22e+04 and relative error of 0.29
# Iteration 20: with minibatch training loss = 4.35e+04 and relative error of 0.4
# Iteration 40: with minibatch training loss = 3.38e+04 and relative error of 0.3
# Iteration 60: with minibatch training loss = 5.35e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 4.94e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 6.42e+04 and relative error of 0.23
# Epoch 28, Overall loss = 5.25e+04 and relative error of 0.32
# Validation
# Epoch 1, Overall loss = 9.75e+04 and relative error of 0.311
# Training
# Iteration 0: with minibatch training loss = 4.07e+04 and relative error of 0.25
# Iteration 20: with minibatch training loss = 5.13e+04 and relative error of 0.31
# Iteration 40: with minibatch training loss = 3.36e+04 and relative error of 0.25
# Iteration 60: with minibatch training loss = 7.78e+04 and relative error of 0.27
# Iteration 80: with minibatch training loss = 7.17e+04 and relative error of 0.27
# Iteration 100: with minibatch training loss = 2.22e+04 and relative error of 0.22
# Epoch 29, Overall loss = 5.12e+04 and relative error of 0.315
# Validation
# Epoch 1, Overall loss = 9.73e+04 and relative error of 0.35
# Training
# Iteration 0: with minibatch training loss = 9.85e+04 and relative error of 0.27
# Iteration 20: with minibatch training loss = 3.79e+04 and relative error of 0.28
# Iteration 40: with minibatch training loss = 1.98e+04 and relative error of 0.23
# Iteration 60: with minibatch training loss = 4.4e+04 and relative error of 0.32
# Iteration 80: with minibatch training loss = 1.81e+04 and relative error of 0.32
# Iteration 100: with minibatch training loss = 3.4e+04 and relative error of 0.26
# Epoch 30, Overall loss = 4.41e+04 and relative error of 0.294
# Validation
# Epoch 1, Overall loss = 8.79e+04 and relative error of 0.3
# Training
# Iteration 0: with minibatch training loss = 1.92e+04 and relative error of 0.26
# Iteration 20: with minibatch training loss = 7.43e+04 and relative error of 0.28
# Iteration 40: with minibatch training loss = 3.63e+04 and relative error of 0.31
# Iteration 60: with minibatch training loss = 7.68e+04 and relative error of 0.47
# Iteration 80: with minibatch training loss = 6.27e+04 and relative error of 0.2
# Iteration 100: with minibatch training loss = 4.29e+04 and relative error of 0.37
# Epoch 31, Overall loss = 4.45e+04 and relative error of 0.297
# Validation
# Epoch 1, Overall loss = 1.02e+05 and relative error of 0.282
# Training
# Iteration 0: with minibatch training loss = 3.99e+04 and relative error of 0.28
# Iteration 20: with minibatch training loss = 4.81e+04 and relative error of 0.26
# Iteration 40: with minibatch training loss = 6.12e+04 and relative error of 0.19
# Iteration 60: with minibatch training loss = 4.37e+04 and relative error of 0.27
# Iteration 80: with minibatch training loss = 4.06e+04 and relative error of 0.3
# Iteration 100: with minibatch training loss = 2.83e+04 and relative error of 0.3
# Epoch 32, Overall loss = 4.58e+04 and relative error of 0.282
# Validation
# Epoch 1, Overall loss = 1.28e+05 and relative error of 0.291
# Training
# Iteration 0: with minibatch training loss = 5.52e+04 and relative error of 0.2
# Iteration 20: with minibatch training loss = 2.42e+04 and relative error of 0.34
# Iteration 40: with minibatch training loss = 3.3e+04 and relative error of 0.23
# Iteration 60: with minibatch training loss = 6.39e+04 and relative error of 0.21
# Iteration 80: with minibatch training loss = 6.68e+04 and relative error of 0.26
# Iteration 100: with minibatch training loss = 5.98e+04 and relative error of 0.26
# Epoch 33, Overall loss = 4.28e+04 and relative error of 0.281
# Validation
# Epoch 1, Overall loss = 8.54e+04 and relative error of 0.295
# Training
# Iteration 0: with minibatch training loss = 3.26e+04 and relative error of 0.23
# Iteration 20: with minibatch training loss = 3.17e+04 and relative error of 0.41
# Iteration 40: with minibatch training loss = 4.19e+04 and relative error of 0.33
# Iteration 60: with minibatch training loss = 3.99e+04 and relative error of 0.48
# Iteration 80: with minibatch training loss = 4.2e+04 and relative error of 0.22
# Iteration 100: with minibatch training loss = 3.98e+04 and relative error of 0.2
# Epoch 34, Overall loss = 4.28e+04 and relative error of 0.275
# Validation
# Epoch 1, Overall loss = 9.44e+04 and relative error of 0.293
# Training
# Iteration 0: with minibatch training loss = 1.92e+04 and relative error of 0.19
# Iteration 20: with minibatch training loss = 3.49e+04 and relative error of 0.27
# Iteration 40: with minibatch training loss = 2.76e+04 and relative error of 0.41
# Iteration 60: with minibatch training loss = 5.44e+04 and relative error of 0.28
# Iteration 80: with minibatch training loss = 3.14e+04 and relative error of 0.21
# Iteration 100: with minibatch training loss = 5.3e+04 and relative error of 0.34
# Epoch 35, Overall loss = 4.29e+04 and relative error of 0.258
# Validation
# Epoch 1, Overall loss = 9.59e+04 and relative error of 0.258
# Training
# Iteration 0: with minibatch training loss = 7.08e+04 and relative error of 0.22
# Iteration 20: with minibatch training loss = 2.25e+04 and relative error of 0.18
# Iteration 40: with minibatch training loss = 4.84e+04 and relative error of 0.15
# Iteration 60: with minibatch training loss = 2.76e+04 and relative error of 0.19
# Iteration 80: with minibatch training loss = 3.66e+04 and relative error of 0.34
# Iteration 100: with minibatch training loss = 6.23e+04 and relative error of 0.24
# Epoch 36, Overall loss = 4.07e+04 and relative error of 0.251
# Validation
# Epoch 1, Overall loss = 8.71e+04 and relative error of 0.207
# Training
# Iteration 0: with minibatch training loss = 2.6e+04 and relative error of 0.25
# Iteration 20: with minibatch training loss = 3.74e+04 and relative error of 0.29
# Iteration 40: with minibatch training loss = 4.04e+04 and relative error of 0.29
# Iteration 60: with minibatch training loss = 3.92e+04 and relative error of 0.3
# Iteration 80: with minibatch training loss = 2.17e+04 and relative error of 0.16
# Iteration 100: with minibatch training loss = 5.23e+04 and relative error of 0.22
# Epoch 37, Overall loss = 4.52e+04 and relative error of 0.258
# Validation
# Epoch 1, Overall loss = 9.62e+04 and relative error of 0.25
# Training
# Iteration 0: with minibatch training loss = 2.64e+04 and relative error of 0.18
# Iteration 20: with minibatch training loss = 3.82e+04 and relative error of 0.24
# Iteration 40: with minibatch training loss = 1.51e+04 and relative error of 0.19
# Iteration 60: with minibatch training loss = 4.09e+04 and relative error of 0.26
# Iteration 80: with minibatch training loss = 3.4e+04 and relative error of 0.31
# Iteration 100: with minibatch training loss = 7.57e+04 and relative error of 0.36
# Epoch 38, Overall loss = 3.68e+04 and relative error of 0.241
# Validation
# Epoch 1, Overall loss = 8.94e+04 and relative error of 0.249
# Training
# Iteration 0: with minibatch training loss = 4.65e+04 and relative error of 0.23
# Iteration 20: with minibatch training loss = 2.85e+04 and relative error of 0.3
# Iteration 40: with minibatch training loss = 2.4e+04 and relative error of 0.14
# Iteration 60: with minibatch training loss = 2.94e+04 and relative error of 0.31
# Iteration 80: with minibatch training loss = 3.57e+04 and relative error of 0.17
# Iteration 100: with minibatch training loss = 4.69e+04 and relative error of 0.12
# Epoch 39, Overall loss = 4.08e+04 and relative error of 0.219
# Validation
# Epoch 1, Overall loss = 1.05e+05 and relative error of 0.364
# Training
# Iteration 0: with minibatch training loss = 3.27e+04 and relative error of 0.27
# Iteration 20: with minibatch training loss = 8.11e+04 and relative error of 0.24
# Iteration 40: with minibatch training loss = 6.03e+04 and relative error of 0.2
# Iteration 60: with minibatch training loss = 7.5e+04 and relative error of 0.51
# Iteration 80: with minibatch training loss = 5.53e+04 and relative error of 0.29
# Iteration 100: with minibatch training loss = 4.81e+04 and relative error of 0.37
# Epoch 40, Overall loss = 7.29e+04 and relative error of 0.372
# Validation
# Epoch 1, Overall loss = 1.01e+05 and relative error of 0.251
# Model saved in file: cnn_depth6_wider.ckpt

# %%
# keep training
num_epochs = 20
for epoch_idx in range(num_epochs):
    print('Training')
    train_loss, train_error = run_model(sess, pred_y_var, mean_loss,
                                        x_var,y_var,is_training,
                                        X_train, y_train, epoch_idx, 100, 20, train_step,False)
    print('Validation')
    val_loss, val_error = run_model(sess, pred_y_var, mean_loss,
                                    x_var, y_var, is_training, X_val, y_val)
    
    train_loss_hist.append(train_loss)
    train_error_hist.append(train_error)
    val_loss_hist.append(val_loss)
    val_error_hist.append(val_error)

# Saving the model
model_name = "cnn_depth6_wider"
saver = tf.train.Saver()
save_path = saver.save(sess, model_name + ".ckpt")
print("Model saved in file: %s" % save_path)

# Saving training history
train_loss = np.array(train_loss_hist)
np.save(model_name+"_train_loss", train_loss)
train_error = np.array(train_error_hist)
np.save(model_name+"_train_error", train_error)
val_loss = np.array(val_loss_hist)
np.save(model_name+"_val_loss", val_loss)
val_error = np.array(val_error_hist)
np.save(model_name+"_val_error", val_error)

# %%
# loading the model
saver = tf.train.Saver()
sess = tf.Session()
save_path = "./cnn_depth6_wider.ckpt"
saver.restore(sess, save_path)
print("Model restored.")
# Out:
# Model restored.

# %%
# Plotting final results
# plot training loss history
plt.plot(train_loss_hist,label= 'training loss history')
plt.plot(val_loss_hist,label= 'validation loss history')
plt.yscale('log')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('training loss')
plt.legend()
plt.savefig('train_val_loss_history.png', bbox_inches='tight')
plt.show()

# %%
# plot relative error history
plt.plot(train_error_hist[7:], label='training relative error')
plt.plot(val_error_hist[7:], label='validation relative error')
plt.grid(True)
plt.xlabel('Epoch number')
plt.ylabel('relative error')
plt.legend()
plt.savefig('relative_error.png', bbox_inches='tight')
plt.show()

# %%
test_out = sess.run(pred_y_var, {x_var: images_test, is_training:False})
plt.plot(test_out)
plt.plot(pv_test)
plt.show()

# %%
idx1 = np.arange(0,491) # a sunny day at 12-20-16
idx2 = np.arange(2730,3145) # a cloudy day at 1-1-17
idx3 = np.arange(5420,5843) # a rainy  day at 1-8-17

idx = np.concatenate((idx1,idx2,idx3))

print(idx.shape)
# Out:
# (1329,)

# %%
idx= idx
feed_dict = {x_var: images[idx],y_var: pv_out[idx],is_training: False}

mse,pred_y_value = sess.run([mean_loss,pred_y_var], feed_dict=feed_dict)

plt.plot(pv_out[idx], label='actual pv output')
plt.plot(pred_y_value, label='predicted pv output')
plt.grid(True)
plt.xlabel('image index')
plt.ylabel('panel output (Btu/hr)')
plt.legend()
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.rc('font',size=15)

plt.savefig('predicted_and_actual_output.png', bbox_inches='tight')
plt.show()

print('RMSE: ', np.sqrt(mse))
# Out:
# RMSE:  159.738
